# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/US/new/
# Out:
# /content/drive/.shortcut-targets-by-id/1h1TFIZAPo8_ggT-9j-rl1rLbykLgg4L7/US/new

# %% [markdown]
# # Twitter Sentiment Analysis

# %% [markdown]
# ## ⚙️ Environment Setup

# %%
# !pip install contractions
import os
import re
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import contractions
import tensorflow as tf
import torch
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
from transformers import AutoTokenizer, AutoModel

warnings.filterwarnings('ignore')
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.3.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (13 kB)
# Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 12.4 MB/s eta 0:00:00
# Downloading pyahocorasick-2.3.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.8/114.8 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.3 contractions-0.1.73 pyahocorasick-2.3.1 textsearch-0.0.24

# %% [markdown]
# ### 🔒 Reproducibility Configuration

# %%
# --- Reproducibility ---
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
torch.manual_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

print(f"TensorFlow version: {tf.__version__}")
print(f"PyTorch version: {torch.__version__}")
print(f"GPU (TF): {tf.config.list_physical_devices('GPU')}")
print(f"GPU (Torch): {torch.cuda.is_available()}")

# Detect device for PyTorch embedding extraction
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {DEVICE}")
# Out:
# TensorFlow version: 2.20.0
# PyTorch version: 2.11.0+cu128
# GPU (TF): [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU (Torch): True
# Using device: cuda

# %% [markdown]
# ---
# ## 📊 Step 1: Data Loading & EDA

# %% [markdown]
# ### 1.1 Load Dataset

# %%
df = pd.read_csv('/content/merged_twitter_sentiment.csv')
print(f"Dataset shape: {df.shape}")
print(f"\nNull values:\n{df.isnull().sum()}")
# Out:
# Dataset shape: (50822, 4)
#
# Null values:
# id             0
# topic          0
# sentiment      0
# text         264
# dtype: int64

# %% [markdown]
# ### 1.2 Class Distribution

# %%
print(f"\n--- Sentiment Distribution ---")
sent_counts = df['sentiment'].value_counts()
sent_pct = df['sentiment'].value_counts(normalize=True) * 100
for s in sent_counts.index:
    print(f"  {s}: {sent_counts[s]} ({sent_pct[s]:.1f}%)")
# Out:
# --- Sentiment Distribution ---
#   Negative: 18785 (37.0%)
#   Positive: 18241 (35.9%)
#   Neutral: 9945 (19.6%)
#   Irrelevant: 3851 (7.6%)

# %% [markdown]
# ### 1.3 Topic Distribution

# %%
print(f"\nUnique topics ({df['topic'].nunique()}): {df['topic'].unique().tolist()}")
print(f"\n--- Topic Distribution ---")
print(df['topic'].value_counts().to_string())
# Out:
# Unique topics (13): ['Amazon', 'Xbox(Xseries)', 'PlayStation5(PS5)', 'Google', 'League Of Legends', 'Microsoft', 'Verizon', 'HomeDepot', 'Facebook', 'johnson&johnson', 'Nvidia', 'Apple', 'hotel']
#
# --- Topic Distribution ---
# topic
# hotel                23113
# League Of Legends     2431
# Microsoft             2428
# Verizon               2414
# Facebook              2403
# johnson&johnson       2367
# Xbox(Xseries)         2360
# Amazon                2350
# PlayStation5(PS5)     2343
# Nvidia                2333
# HomeDepot             2328
# Google                2322
# Apple                 1630

# %% [markdown]
# ### 1.4 Sample Rows

# %%
print(f"\n--- Sample Rows ---")
print(df.head(5).to_string())
# Out:
# --- Sample Rows ---
#    id   topic sentiment            text
# 0   0  Amazon  Negative  @amazon wtf .
# 1   1  Amazon  Negative   @ amazon wtf.
# 2   2  Amazon  Negative   @ amazon wtf.
# 3   3  Amazon  Negative    @amazon wtf?
# 4   4  Amazon  Negative  7 @amazon wtf.

# %% [markdown]
# ### 1.5 Visualization: Sentiment & Topic Distribution

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Sentiment bar chart
colors_sent = ['#e74c3c', '#3498db', '#2ecc71', '#95a5a6']
ax1 = axes[0]
df['sentiment'].value_counts().plot(kind='bar', ax=ax1, color=colors_sent, edgecolor='black')
ax1.set_title('Sentiment Distribution', fontsize=14, fontweight='bold')
ax1.set_xlabel('Sentiment')
ax1.set_ylabel('Count')
ax1.tick_params(axis='x', rotation=45)
for i, (val, count) in enumerate(df['sentiment'].value_counts().items()):
    ax1.text(i, count + 200, str(count), ha='center', fontweight='bold')

# Topic bar chart
ax2 = axes[1]
df['topic'].value_counts().plot(kind='bar', ax=ax2, color='#1abc9c', edgecolor='black')
ax2.set_title('Topic Distribution', fontsize=14, fontweight='bold')
ax2.set_xlabel('Topic')
ax2.set_ylabel('Count')
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('eda_distribution.png', dpi=150, bbox_inches='tight')
plt.show()
print("Saved: eda_distribution.png")
# Out:
# Saved: eda_distribution.png

# %% [markdown]
# ---
# ## 🧹 Step 2: Preprocessing

# %% [markdown]
# ### 2.1 Filter: Keep only Positive / Neutral / Negative

# %%
print(f"Before filtering: {len(df)} rows")
df = df[df['sentiment'].isin(['Positive', 'Neutral', 'Negative'])].copy()
print(f"After removing 'Irrelevant': {len(df)} rows")

# --- Drop nulls in text/sentiment ---
df.dropna(subset=['text', 'sentiment'], inplace=True)
print(f"After dropping nulls: {len(df)} rows")
# Out:
# Before filtering: 50822 rows
# After removing 'Irrelevant': 46971 rows
# After dropping nulls: 46773 rows

# %% [markdown]
# ### 2.2 Text Cleaning Function

# %%
def clean_text(text):
    """Clean tweet text for model input."""
    if not isinstance(text, str):
        return ""
    text = text.lower()
    text = re.sub(r'http\S+|www\S+', '', text)          # Remove URLs
    text = re.sub(r'@\w+', '', text)                     # Remove @mentions
    text = re.sub(r'#\w+', '', text)                     # Remove #hashtags
    try:
        text = contractions.fix(text)                     # Expand contractions
    except Exception:
        pass
    text = re.sub(r'[^a-zA-Z\s]', '', text)              # Keep letters & spaces only
    text = re.sub(r'\s+', ' ', text).strip()              # Strip extra whitespace
    return text

# Apply cleaning
df['clean_text'] = df['text'].apply(clean_text)

# Remove rows where cleaning resulted in empty string
df = df[df['clean_text'].str.len() > 0].copy()
print(f"After text cleaning: {len(df)} rows")
print(f"\nSample cleaned text:")
print(df[['text', 'clean_text']].head(3).to_string())
# Out:
# After text cleaning: 46661 rows
#
# Sample cleaned text:
#              text  clean_text
# 0  @amazon wtf .          wtf
# 1   @ amazon wtf.  amazon wtf
# 2   @ amazon wtf.  amazon wtf

# %% [markdown]
# ### 2.2b Duplicate Check After Cleaning
#
# The cleaning step above is aggressive (strips URLs, @mentions, #hashtags, digits, punctuation), so
# different raw tweets can collapse onto the same `clean_text` string (e.g. `"@amazon wtf ."` and
# `"@ amazon wtf."` both become `"amazon wtf"`). Duplicated `clean_text` rows that land on opposite
# sides of the train/val/test split are a **train/test leak** — the model can "memorize" a training
# duplicate instead of generalizing. Check and remove them *before* splitting.

# %%
# clean_text groups can be ambiguous in two ways: (1) the SAME clean_text maps to different
# sentiment labels (the aggressive cleaning discarded whatever originally distinguished them), or
# (2) the same clean_text maps to different topics. Naively keeping the first occurrence
# (keep='first') would pick a label based on row order alone, not any meaningful rule -- e.g.
# clean_text == "a" appears with Negative, Neutral AND Positive labels across 9 different topics.
# Drop those ambiguous groups entirely first, then dedupe the (now label-consistent) remainder.
dup_mask = df['clean_text'].duplicated(keep=False)
n_dup_rows = dup_mask.sum()

print(f"clean_text duplicate check:")
print(f"  Rows sharing clean_text with >=1 other row: {n_dup_rows} ({n_dup_rows/len(df)*100:.1f}%)")

if n_dup_rows > 0:
    grp = df.groupby('clean_text')
    ambiguous_sentiment = grp['sentiment'].nunique() > 1
    ambiguous_topic = grp['topic'].nunique() > 1
    ambiguous_texts = set(ambiguous_sentiment[ambiguous_sentiment].index) | set(ambiguous_topic[ambiguous_topic].index)

    print(f"  clean_text groups with >1 sentiment label: {int(ambiguous_sentiment.sum())}")
    print(f"  clean_text groups with >1 topic label:     {int(ambiguous_topic.sum())}")
    print(f"  Combined ambiguous groups (either):        {len(ambiguous_texts)}")

    ambiguous_row_mask = df['clean_text'].isin(ambiguous_texts)
    print("\nExample ambiguous groups (dropped entirely — no reliable single label):")
    print(df[ambiguous_row_mask].sort_values('clean_text')[['id', 'text', 'clean_text', 'sentiment', 'topic']].head(9).to_string())

    before = len(df)
    df = df[~ambiguous_row_mask].copy()
    n_ambiguous_dropped = before - len(df)
    print(f"\nDropped {n_ambiguous_dropped} rows belonging to an ambiguous-label clean_text group.")

    # Remaining duplicate groups are now label-consistent (same sentiment AND same topic) —
    # safe to keep just one row per group.
    before_dedup = len(df)
    df = df.drop_duplicates(subset='clean_text', keep='first').reset_index(drop=True)
    n_consistent_dropped = before_dedup - len(df)
    print(f"Dropped {n_consistent_dropped} additional duplicate rows from label-consistent groups.")
    print(f"Total dropped: {n_ambiguous_dropped + n_consistent_dropped} -> {len(df)} rows remain (was {before} going into the split).")
else:
    print("\nNo duplicates found — dataset unchanged.")

# --- Export the final filtered + deduplicated id list (reproducibility artifact, see Step 10) ---
os.makedirs('./artifacts', exist_ok=True)
df[['id']].to_csv('./artifacts/filtered_ids.csv', index=False)
print(f"Saved {len(df)} ids used for train/val/test splitting -> ./artifacts/filtered_ids.csv")
# Out:
# clean_text duplicate check:
#   Rows sharing clean_text with >=1 other row: 3417 (7.3%)
#   clean_text groups with >1 sentiment label: 55
#   clean_text groups with >1 topic label:     93
#   Combined ambiguous groups (either):        97
#
# Example ambiguous groups (dropped entirely — no reliable single label):
#           id       text clean_text sentiment              topic
# 3263    3263          a          a   Neutral      Xbox(Xseries)
# 20492  20492  Awwww....          a  Positive           Facebook
# 20491  20491  Awwww....          a  Positive           Facebook
# 20490  20490  Awwww....          a  Positive           Facebook
# 20015  20015          a          a  Positive           Facebook
# 20493  20493  Awwww....          a  Positive           Facebook
# 7885    7885    Awwwww.          a  Negative             Google
# 773      773          a          a  Negative             Amazon
# 11159  11159          a          a  Positive  League Of Legends
#
# Dropped 778 rows belonging to an ambiguous-label clean_text group.
# Dropped 1487 additional duplicate rows from label-consistent groups.
# Total dropped: 2265 -> 44396 rows remain (was 46661 going into the split).
# Saved 44396 ids used for train/val/test splitting -> ./artifacts/filtered_ids.csv

# %% [markdown]
# ### 2.2c Cleaning Variant — "Light" Cleaning (keeps digits & hashtag words)
#
# `clean_text()` above strips `#hashtags` down to nothing and removes every digit, but tokens like
# `#fail` or `10/10` can carry real sentiment signal. Define a lighter variant that only strips the
# `#` character (keeping the word underneath) and keeps digits, so the two variants can be compared
# head-to-head later as TF-IDF + Logistic Regression baselines (Step 6.5, Baseline E) to quantify the
# accuracy delta this cleaning choice costs.

# %%
def clean_text_light(text):
    """Lighter cleaning: strip URLs/mentions, unwrap '#tag' -> 'tag', keep digits and letters."""
    if not isinstance(text, str):
        return ""
    text = text.lower()
    text = re.sub(r'http\S+|www\S+', '', text)          # Remove URLs
    text = re.sub(r'@\w+', '', text)                     # Remove @mentions
    text = re.sub(r'#(\w+)', r'\1', text)                 # Unwrap hashtags: '#fail' -> 'fail'
    try:
        text = contractions.fix(text)
    except Exception:
        pass
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)            # Keep letters, digits & spaces
    text = re.sub(r'\s+', ' ', text).strip()
    return text

df['clean_text_light'] = df['text'].apply(clean_text_light)
n_empty_light = (df['clean_text_light'].str.len() == 0).sum()
n_dup_light = df['clean_text_light'].duplicated().sum()
print(f"Light cleaning: {n_empty_light} rows become empty, {n_dup_light} duplicate clean_text_light rows.")
print(f"(Main cleaning already dropped all empty/duplicate rows above, so this doesn't drop rows here —\n"
      f" it's used purely as an alternate feature column for the Baseline E delta comparison in Step 6.5.)")

print("\nSample: main clean_text vs clean_text_light")
print(df[['text', 'clean_text', 'clean_text_light']].sample(5, random_state=SEED).to_string())
# Out:
# Light cleaning: 0 rows become empty, 0 duplicate clean_text_light rows.
# (Main cleaning already dropped all empty/duplicate rows above, so this doesn't drop rows here —
#  it's used purely as an alternate feature column for the Baseline E delta comparison in Step 6.5.)
#
# Sample: main clean_text vs clean_text_light
#                                                                                                                                                                                text                                                                                                                                                                clean_text                                                                                                                                                          clean_text_light
# 35985                                                                                                                                             The breakfast was very delicious.                                                                                                                                          the breakfast was very delicious                                                                                                                                          the breakfast was very delicious
# 14881                                                                          That ’ how s my momma account?. cause that tattoo ’ s definitely what something she ’ d still do smh                                                                            that how s my momma account because that tattoo s definitely what something she d still do smh                                                                            that how s my momma account because that tattoo s definitely what something she d still do smh
# 12845                                                                                                                                                             Stop the bleeding                                                                                                                                                         stop the bleeding                                                                                                                                                         stop the bleeding
# 23315                                                                                                                                                     Breakfast service is bad.                                                                                                                                                  breakfast service is bad                                                                                                                                                  breakfast service is bad
# 14840  Dumbas on Facebook tries to say that violence by law enforcement against minorities has nothing to do with racism, and then cites the video of Ben Sharpio as an argument...  dumbas on facebook tries to say that violence by law enforcement against minorities has nothing to do with racism and then cites the video of ben sharpio as an argument  dumbas on facebook tries to say that violence by law enforcement against minorities has nothing to do with racism and then cites the video of ben sharpio as an argument

# %% [markdown]
# ### 2.3 Label Encoding

# %%
sentiment_encoder = LabelEncoder()
df['sentiment_encoded'] = sentiment_encoder.fit_transform(df['sentiment'])
print(f"\nSentiment classes: {sentiment_encoder.classes_.tolist()}")
print(f"Encoded mapping: {dict(zip(sentiment_encoder.classes_, sentiment_encoder.transform(sentiment_encoder.classes_)))}")

topic_encoder = LabelEncoder()
df['topic_encoded'] = topic_encoder.fit_transform(df['topic'])
print(f"\nTopic classes ({len(topic_encoder.classes_)}): {topic_encoder.classes_.tolist()}")
# Out:
# Sentiment classes: ['Negative', 'Neutral', 'Positive']
# Encoded mapping: {'Negative': np.int64(0), 'Neutral': np.int64(1), 'Positive': np.int64(2)}
#
# Topic classes (13): ['Amazon', 'Apple', 'Facebook', 'Google', 'HomeDepot', 'League Of Legends', 'Microsoft', 'Nvidia', 'PlayStation5(PS5)', 'Verizon', 'Xbox(Xseries)', 'hotel', 'johnson&johnson']

# %% [markdown]
# ### 2.4 Train / Val / Test Split (70 / 15 / 15)

# %%
X_text = df['clean_text'].values
X_raw_text = df['text'].values
y_sentiment = df['sentiment_encoded'].values
topic_ids = df['topic_encoded'].values

# First split: 70% train, 30% temp
X_train_text, X_temp_text, X_train_raw, X_temp_raw, y_train, y_temp, topic_train, topic_temp = train_test_split(
    X_text, X_raw_text, y_sentiment, topic_ids,
    test_size=0.30, stratify=y_sentiment, random_state=SEED
)

# Second split: 50/50 of temp → 15% val, 15% test
X_val_text, X_test_text, X_val_raw, X_test_raw, y_val, y_test, topic_val, topic_test = train_test_split(
    X_temp_text, X_temp_raw, y_temp, topic_temp,
    test_size=0.50, stratify=y_temp, random_state=SEED
)

# X_*_raw carries the original (uncleaned) tweet text, aligned index-for-index with the
# corresponding clean-text/label/topic arrays — needed for the zero-shot RoBERTa baseline
# (Step 6.5) and the counterfactual flip-rate experiment (Step 9.3), both of which need the
# raw tweet rather than the aggressively-cleaned text.

# %% [markdown]
# ### 2.5 Split Summary

# %%
for name, y_split in [('Train', y_train), ('Val', y_val), ('Test', y_test)]:
    print(f"\n{name} set: {len(y_split)} samples")
    for cls_idx, cls_name in enumerate(sentiment_encoder.classes_):
        count = (y_split == cls_idx).sum()
        print(f"  {cls_name}: {count} ({count/len(y_split)*100:.1f}%)")
# Out:
# Train set: 31077 samples
#   Negative: 12601 (40.5%)
#   Neutral: 6369 (20.5%)
#   Positive: 12107 (39.0%)
#
# Val set: 6659 samples
#   Negative: 2700 (40.5%)
#   Neutral: 1365 (20.5%)
#   Positive: 2594 (39.0%)
#
# Test set: 6660 samples
#   Negative: 2700 (40.5%)
#   Neutral: 1365 (20.5%)
#   Positive: 2595 (39.0%)

# %% [markdown]
# ---
# ## 🤖 Step 3: RoBERTa Embedding Extraction & TensorFlow Dataset

# %% [markdown]
# ### 3.1 Load RoBERTa Tokenizer & Model (PyTorch)

# %%
MODEL_NAME = 'cardiffnlp/twitter-roberta-base-sentiment-latest'
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
roberta_model = AutoModel.from_pretrained(MODEL_NAME)
roberta_model.to(DEVICE)
roberta_model.eval()  # Inference mode — no gradient needed
print(f"Loaded PyTorch model: {MODEL_NAME}")
print(f"Model on device: {next(roberta_model.parameters()).device}")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B /  501MB
# pytorch_model.bin: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] RobertaModel LOAD REPORT from: cardiffnlp/twitter-roberta-base-sentiment-latest
# Key                        | Status     |  |
# ---------------------------+------------+--+-
# classifier.out_proj.weight | UNEXPECTED |  |
# classifier.out_proj.bias   | UNEXPECTED |  |
# classifier.dense.weight    | UNEXPECTED |  |
# classifier.dense.bias      | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors: reconstructing file:   0%|          |  0.00B /  501MB
# model.safetensors: downloading bytes:           |  0.00B
# Loaded PyTorch model: cardiffnlp/twitter-roberta-base-sentiment-latest
# Model on device: cuda:0

# %% [markdown]
# ### 3.2 Mean Pooling & Batch Extraction Function

# %%
MAX_LEN = 128
EMBED_BATCH_SIZE = 64  # Batch size for embedding extraction (no gradients → can be larger)

def mean_pooling(last_hidden_state, attention_mask):
    """
    Mean pooling: average all token embeddings weighted by attention_mask.
    Much better than [CLS]-only — captures full sentence context.
    """
    # attention_mask: (batch, seq_len) → expand to (batch, seq_len, hidden_dim)
    mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
    sum_embeddings = torch.sum(last_hidden_state * mask_expanded, dim=1)
    sum_mask = torch.clamp(mask_expanded.sum(dim=1), min=1e-9)
    return sum_embeddings / sum_mask

def extract_embeddings(texts, batch_size=EMBED_BATCH_SIZE):
    """
    Extract mean-pooled embeddings from RoBERTa using PyTorch.
    Returns numpy array of shape (N, 768).
    """
    all_embeddings = []
    total = len(texts)

    for i in range(0, total, batch_size):
        batch_texts = texts[i:i+batch_size].tolist()

        # Tokenize batch
        encoding = tokenizer(
            batch_texts,
            max_length=MAX_LEN,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )

        # Move to GPU if available
        input_ids = encoding['input_ids'].to(DEVICE)
        attention_mask = encoding['attention_mask'].to(DEVICE)

        # Forward pass — no gradients needed for feature extraction
        with torch.no_grad():
            outputs = roberta_model(input_ids=input_ids, attention_mask=attention_mask)

        # Mean pooling over all tokens (weighted by attention mask)
        embeddings = mean_pooling(outputs.last_hidden_state, attention_mask).cpu().numpy()
        all_embeddings.append(embeddings)

        if (i // batch_size) % 20 == 0:
            print(f"  Processed {min(i+batch_size, total)}/{total} texts...")

    return np.concatenate(all_embeddings, axis=0)

# %% [markdown]
# ### 3.3 Extract Embeddings for All Splits

# %%
print("\n--- Extracting Train embeddings (mean pooling) ---")
train_embeddings = extract_embeddings(X_train_text)
print(f"Train embeddings shape: {train_embeddings.shape}")

print("\n--- Extracting Val embeddings (mean pooling) ---")
val_embeddings = extract_embeddings(X_val_text)
print(f"Val embeddings shape: {val_embeddings.shape}")

print("\n--- Extracting Test embeddings (mean pooling) ---")
test_embeddings = extract_embeddings(X_test_text)
print(f"Test embeddings shape: {test_embeddings.shape}")

# Free GPU memory after extraction
del roberta_model
if torch.cuda.is_available():
    torch.cuda.empty_cache()
print("\n Embeddings extracted! RoBERTa model freed from GPU.")
# Out:
# --- Extracting Train embeddings (mean pooling) ---
#   Processed 64/31077 texts...
#   Processed 1344/31077 texts...
#   Processed 2624/31077 texts...
#   Processed 3904/31077 texts...
#   Processed 5184/31077 texts...
#   Processed 6464/31077 texts...
#   Processed 7744/31077 texts...
#   Processed 9024/31077 texts...
#   Processed 10304/31077 texts...
#   Processed 11584/31077 texts...
#   Processed 12864/31077 texts...
#   Processed 14144/31077 texts...
#   Processed 15424/31077 texts...
#   Processed 16704/31077 texts...
#   Processed 17984/31077 texts...
#   Processed 19264/31077 texts...
#   Processed 20544/31077 texts...
#   Processed 21824/31077 texts...
#   Processed 23104/31077 texts...
#   Processed 24384/31077 texts...
#   Processed 25664/31077 texts...
#   Processed 26944/31077 texts...
#   Processed 28224/31077 texts...
#   Processed 29504/31077 texts...
#   Processed 30784/31077 texts...
# Train embeddings shape: (31077, 768)
#
# --- Extracting Val embeddings (mean pooling) ---
#   Processed 64/6659 texts...
#   Processed 1344/6659 texts...
#   Processed 2624/6659 texts...
#   Processed 3904/6659 texts...
#   Processed 5184/6659 texts...
#   Processed 6464/6659 texts...
# Val embeddings shape: (6659, 768)
#
# --- Extracting Test embeddings (mean pooling) ---
#   Processed 64/6660 texts...
#   Processed 1344/6660 texts...
#   Processed 2624/6660 texts...
#   Processed 3904/6660 texts...
#   Processed 5184/6660 texts...
#   Processed 6464/6660 texts...
# Test embeddings shape: (6660, 768)
#
#  Embeddings extracted! RoBERTa model freed from GPU.

# %% [markdown]
# ### 3.4 Auto Topic Classifier (feeds the main model — not the ground-truth topic)
#
# Train a topic classifier — TF-IDF (on `clean_text`) + Logistic Regression, with vocabulary size and
# regularization strength `C` chosen by 5-fold cross-validation — *before* building the main model.
# Its **predicted** topic — not the dataset's ground-truth `topic` column — is what gets fed into the
# dual-input model's `topic_id` input from here on (the Step 3.5 TF Datasets below, Step 4's model,
# Step 6.5's Baseline C, and Step 7's inference demo). This matches real deployment, where the true
# topic isn't available and has to be predicted from the tweet itself, and it means the main model is
# trained on the same (imperfect) topic signal it will actually see at inference time, instead of a
# ground-truth label it will never get outside of this dataset.
#
# An earlier version of this classifier used the RoBERTa sentiment embeddings as features and could
# not close the train/val gap without losing val/test accuracy — those embeddings come from a
# sentiment-tuned checkpoint, so topic signal was diluted across all 768 dims. Topic in this dataset
# is overwhelmingly lexical (brand names appear verbatim in the tweets), so TF-IDF on the tweet text
# itself gives the classifier a far more direct, task-relevant signal.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.utils import shuffle

# Shuffle the training rows (text + topic labels stay paired) before cross-validation.
X_train_text_shuf, topic_train_shuf = shuffle(X_train_text, topic_train, random_state=SEED)

# Switched from RoBERTa-embedding features to TF-IDF: the embeddings come from a SENTIMENT-tuned
# checkpoint, so topic signal was entangled/diluted across all 768 dims, and no amount of
# regularization on that representation could close the train/val gap without also losing val/test
# accuracy (see the earlier attempts in this cell's history). Topic in this dataset is
# overwhelmingly lexical — brand names ("amazon", "xbox", "playstation", "google", ...) appear
# verbatim in the tweets — so TF-IDF on `clean_text` gives the classifier a far more direct,
# task-relevant signal to work with, instead of trying to disentangle it from sentiment features.
topic_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1, 2), min_df=2)),
    ('clf', LogisticRegression(max_iter=2000, class_weight='balanced', random_state=SEED)),
])

param_grid = {
    'tfidf__max_features': [5000, 10000, 20000],
    'clf__C': [0.1, 1.0, 10.0],
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
grid = GridSearchCV(topic_pipeline, param_grid, cv=cv, scoring='accuracy', n_jobs=-1)
grid.fit(X_train_text_shuf, topic_train_shuf)

topic_clf = grid.best_estimator_
print(f"Best params: {grid.best_params_}  (5-fold CV accuracy: {grid.best_score_:.4f})")

topic_train_pred = topic_clf.predict(X_train_text)
topic_val_pred = topic_clf.predict(X_val_text)
topic_test_pred = topic_clf.predict(X_test_text)

print(f"Topic classifier — Train accuracy: {accuracy_score(topic_train, topic_train_pred):.4f}")
print(f"Topic classifier — Val accuracy:   {accuracy_score(topic_val, topic_val_pred):.4f}")
print(f"Topic classifier — Test accuracy:  {accuracy_score(topic_test, topic_test_pred):.4f}")
print(f"Topic classifier — Test macro-F1:  {f1_score(topic_test, topic_test_pred, average='macro'):.4f}")


def predict_topic_from_text(cleaned_text):
    """cleaned_text: already clean_text()-ed tweet string -> predicted topic string."""
    topic_id_pred = topic_clf.predict([cleaned_text])[0]
    return topic_encoder.inverse_transform([topic_id_pred])[0]
# Out:
# Best params: {'clf__C': 10.0, 'tfidf__max_features': 20000}  (5-fold CV accuracy: 0.9490)
# Topic classifier — Train accuracy: 0.9946
# Topic classifier — Val accuracy:   0.9513
# Topic classifier — Test accuracy:  0.9544
# Topic classifier — Test macro-F1:  0.9212

# %% [markdown]
# ### 3.5 Create TensorFlow Datasets

# %%
BATCH_TRAIN = 16
BATCH_EVAL = 32
BUFFER_SIZE = 1000

def make_tf_dataset(embeddings, topic_ids, labels, batch_size, shuffle=False):
    """Create a tf.data.Dataset with pre-extracted embeddings + topic input."""
    dataset = tf.data.Dataset.from_tensor_slices((
        {
            'text_embedding': embeddings.astype(np.float32),
            'topic_id': topic_ids.reshape(-1, 1)
        },
        labels
    ))
    if shuffle:
        dataset = dataset.shuffle(buffer_size=BUFFER_SIZE, seed=SEED)
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset

# Use the AUTO-PREDICTED topic (Step 3.5) as the model's topic_id input, not the ground-truth
# dataset topic — this makes the main model's training input match real inference, where the
# true topic isn't available and must be predicted from the tweet's own embedding.
train_ds = make_tf_dataset(train_embeddings, topic_train_pred, y_train, BATCH_TRAIN, shuffle=True)
val_ds   = make_tf_dataset(val_embeddings, topic_val_pred, y_val, BATCH_EVAL)
test_ds  = make_tf_dataset(test_embeddings, topic_test_pred, y_test, BATCH_EVAL)

# Quick check
for batch_x, batch_y in train_ds.take(1):
    print(f"Batch text_embedding shape: {batch_x['text_embedding'].shape}")
    print(f"Batch topic_id shape: {batch_x['topic_id'].shape}")
    print(f"Batch labels shape: {batch_y.shape}")
    break

print("\n TF Datasets created successfully!")
# Out:
# Batch text_embedding shape: (16, 768)
# Batch topic_id shape: (16, 1)
# Batch labels shape: (16,)
#
#  TF Datasets created successfully!

# %% [markdown]
# ---
# ## 🏗️ Step 4: Model Architecture

# %%
NUM_TOPICS = len(topic_encoder.classes_)  # 12 topics
NUM_CLASSES = len(sentiment_encoder.classes_)  # 3 classes
ROBERTA_DIM = 768  # [CLS] embedding dimension
TOPIC_EMB_DIM = 32
DROPOUT_RATE = 0.4

def build_model(roberta_dim=768, num_topics=12, num_classes=3,
                topic_emb_dim=32, dropout_rate=0.4):
    """
    Improved classification head with BatchNorm + deeper architecture:
    - Text branch: RoBERTa mean-pooled embedding (768-dim) → BatchNorm → Dropout
    - Topic branch: Embedding(num_topics+1, 32) → Flatten
    - Fusion: Concatenate → Dense(512) → BN → Dropout → Dense(256) → BN → Dropout → Dense(64) → Softmax
    """
    # --- Inputs ---
    text_embedding = tf.keras.Input(shape=(roberta_dim,), dtype=tf.float32, name='text_embedding')
    topic_id       = tf.keras.Input(shape=(1,),           dtype=tf.int32,   name='topic_id')

    # --- Text branch: normalize embeddings first ---
    text_vec = tf.keras.layers.BatchNormalization(name='text_bn')(text_embedding)
    text_vec = tf.keras.layers.Dropout(dropout_rate, name='text_dropout')(text_vec)

    # --- Topic branch ---
    topic_vec = tf.keras.layers.Embedding(
        input_dim=num_topics + 1,
        output_dim=topic_emb_dim,
        name='topic_embedding'
    )(topic_id)
    topic_vec = tf.keras.layers.Flatten(name='topic_flatten')(topic_vec)

    # --- Fusion: deeper head with BatchNorm for better gradient flow ---
    combined = tf.keras.layers.Concatenate(name='fusion')([text_vec, topic_vec])
    x = tf.keras.layers.Dense(512, activation='relu', name='dense_512')(combined)
    x = tf.keras.layers.BatchNormalization(name='bn_512')(x)
    x = tf.keras.layers.Dropout(dropout_rate, name='dropout_512')(x)
    x = tf.keras.layers.Dense(256, activation='relu', name='dense_256')(x)
    x = tf.keras.layers.Concatenate(name='skip_connection')([x, combined])  # skip connection
    x = tf.keras.layers.Dense(256, activation='relu', name='dense_256b')(x)
    x = tf.keras.layers.BatchNormalization(name='bn_256')(x)
    x = tf.keras.layers.Dropout(dropout_rate, name='dropout_256')(x)
    x = tf.keras.layers.Dense(64, activation='relu', name='dense_64')(x)
    output = tf.keras.layers.Dense(num_classes, activation='softmax', name='output')(x)

    model = tf.keras.Model(
        inputs=[text_embedding, topic_id],
        outputs=output,
        name='RoBERTa_Topic_Sentiment'
    )
    return model

# %% [markdown]
# ### Compile Model
#
# - **Optimizer:** AdamW (lr=1e-3, weight_decay=0.01) — higher LR since we're training a head on frozen embeddings
# - **Loss:** SparseCategoricalCrossentropy
# - **Label Smoothing:** 0.1 for better generalization

# %%
model = build_model(ROBERTA_DIM, NUM_TOPICS, NUM_CLASSES, TOPIC_EMB_DIM, DROPOUT_RATE)

# Compile
optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=0.01)
model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# %% [markdown]
# ### Model Parameter Summary
#
# Log the parameter count and confirm the initialization seed so a training run is reproducible
# end-to-end. Dense/Embedding kernels use Keras's default `glorot_uniform` initializer, which draws
# from TensorFlow's global RNG — already pinned by `tf.random.set_seed(SEED)` in the Reproducibility
# Configuration cell above, so re-running `build_model()` with the same `SEED` reproduces the same
# initial weights.

# %%
model.summary()

trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_variables])
non_trainable_params = np.sum([np.prod(v.shape) for v in model.non_trainable_variables])
print(f"\nTrainable params:     {trainable_params:,}")
print(f"Non-trainable params: {non_trainable_params:,}")
print(f"Total params:          {trainable_params + non_trainable_params:,}")
print(f"Weight-init seed: SEED={SEED} (global TF seed set via tf.random.set_seed in the Reproducibility cell)")
# Out:
# Model: "RoBERTa_Topic_Sentiment"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ text_embedding      │ (None, 768)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ topic_id            │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ text_bn             │ (None, 768)       │      3,072 │ text_embedding[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ topic_embedding     │ (None, 1, 32)     │        448 │ topic_id[0][0]    │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ text_dropout        │ (None, 768)       │          0 │ text_bn[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ topic_flatten       │ (None, 32)        │          0 │ topic_embedding[… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fusion              │ (None, 800)       │          0 │ text_dropout[0][… │
# │ (Concatenate)       │                   │            │ topic_flatten[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_512 (Dense)   │ (None, 512)       │    410,112 │ fusion[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_512              │ (None, 512)       │      2,048 │ dense_512[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_512         │ (None, 512)       │          0 │ bn_512[0][0]      │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_256 (Dense)   │ (None, 256)       │    131,328 │ dropout_512[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip_connection     │ (None, 1056)      │          0 │ dense_256[0][0],  │
# │ (Concatenate)       │                   │            │ fusion[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_256b (Dense)  │ (None, 256)       │    270,592 │ skip_connection[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_256              │ (None, 256)       │      1,024 │ dense_256b[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_256         │ (None, 256)       │          0 │ bn_256[0][0]      │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_64 (Dense)    │ (None, 64)        │     16,448 │ dropout_256[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 3)         │        195 │ dense_64[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 835,267 (3.19 MB)
#  Trainable params: 832,195 (3.17 MB)
#  Non-trainable params: 3,072 (12.00 KB)
# Trainable params:     832,195
# Non-trainable params: 3,078
# Total params:          835,273
# Weight-init seed: SEED=42 (global TF seed set via tf.random.set_seed in the Reproducibility cell)

# %% [markdown]
# ---
# ## 🏋️ Step 5: Training
#
# Train the classification head with:
# - **Class weights** to handle imbalanced data
# - **EarlyStopping** (patience=5) to prevent overfitting
# - **ReduceLROnPlateau** for adaptive learning rate
# - **ModelCheckpoint** to save best weights

# %% [markdown]
# ### 5.1 Compute Class Weights

# %%
class_weights_arr = compute_class_weight(
    'balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weight_dict = dict(enumerate(class_weights_arr))
print(f"Class weights: {class_weight_dict}")
for idx, name in enumerate(sentiment_encoder.classes_):
    print(f"  {name} (class {idx}): weight = {class_weight_dict[idx]:.4f}")
# Out:
# Class weights: {0: np.float64(0.8220776128878661), 1: np.float64(1.6264719736222326), 2: np.float64(0.855620715288676)}
#   Negative (class 0): weight = 0.8221
#   Neutral (class 1): weight = 1.6265
#   Positive (class 2): weight = 0.8556

# %% [markdown]
# ### 5.2 Setup Callbacks

# %%
os.makedirs('./best_model/', exist_ok=True)

def make_callbacks(patience=5, checkpoint_path='./best_model/model.weights.h5', reduce_lr_patience=3):
    """
    Build a fresh set of callbacks. `patience` is NOT shared across every training run in this
    notebook: the full model (30-epoch budget) uses patience=5, while the 15-epoch ablation runs
    (Step 6.6) use patience=4, so early stopping keeps roughly the same relative "budget" at the
    shorter epoch cap instead of silently reusing the 30-epoch setting.
    """
    ckpt_dir = os.path.dirname(checkpoint_path)
    if ckpt_dir:
        os.makedirs(ckpt_dir, exist_ok=True)
    return [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=patience,
            restore_best_weights=True,
            verbose=1
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=reduce_lr_patience,
            verbose=1,
            min_lr=1e-6
        ),
        tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_path,
            monitor='val_loss',
            save_best_only=True,
            save_weights_only=True,
            verbose=1
        )
    ]

# Full model: 30-epoch budget -> patience=5 (see docstring above)
callbacks = make_callbacks(patience=5, checkpoint_path='./best_model/model.weights.h5')

# %% [markdown]
# ### 5.3 Train the Model

# %%
EPOCHS = 30  # EarlyStopping will halt when needed

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    class_weight=class_weight_dict,
    callbacks=callbacks,
    verbose=1
)

print("\n Training complete!")
# Out:
# Epoch 1/30
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7336 - loss: 0.6837
# Epoch 1: val_loss improved from None to 0.48756, saving model to ./best_model/model.weights.h5
#
# Epoch 1: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.7610 - loss: 0.6056 - val_accuracy: 0.8006 - val_loss: 0.4876 - learning_rate: 0.0010
# Epoch 2/30
# 1931/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7896 - loss: 0.5464
# Epoch 2: val_loss improved from 0.48756 to 0.45936, saving model to ./best_model/model.weights.h5
#
# Epoch 2: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7925 - loss: 0.5324 - val_accuracy: 0.8115 - val_loss: 0.4594 - learning_rate: 0.0010
# Epoch 3/30
# 1939/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7998 - loss: 0.5198
# Epoch 3: val_loss improved from 0.45936 to 0.45897, saving model to ./best_model/model.weights.h5
#
# Epoch 3: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7991 - loss: 0.5126 - val_accuracy: 0.8142 - val_loss: 0.4590 - learning_rate: 0.0010
# Epoch 4/30
# 1935/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8005 - loss: 0.5063
# Epoch 4: val_loss did not improve from 0.45897
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8051 - loss: 0.4963 - val_accuracy: 0.8067 - val_loss: 0.4606 - learning_rate: 0.0010
# Epoch 5/30
# 1938/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8076 - loss: 0.4892
# Epoch 5: val_loss improved from 0.45897 to 0.43952, saving model to ./best_model/model.weights.h5
#
# Epoch 5: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8099 - loss: 0.4852 - val_accuracy: 0.8202 - val_loss: 0.4395 - learning_rate: 0.0010
# Epoch 6/30
# 1935/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8121 - loss: 0.4745
# Epoch 6: val_loss improved from 0.43952 to 0.43046, saving model to ./best_model/model.weights.h5
#
# Epoch 6: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8157 - loss: 0.4699 - val_accuracy: 0.8237 - val_loss: 0.4305 - learning_rate: 0.0010
# Epoch 7/30
# 1940/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8156 - loss: 0.4698
# Epoch 7: val_loss did not improve from 0.43046
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8177 - loss: 0.4650 - val_accuracy: 0.8214 - val_loss: 0.4396 - learning_rate: 0.0010
# Epoch 8/30
# 1942/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8222 - loss: 0.4604
# Epoch 8: val_loss improved from 0.43046 to 0.42092, saving model to ./best_model/model.weights.h5
#
# Epoch 8: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8221 - loss: 0.4583 - val_accuracy: 0.8297 - val_loss: 0.4209 - learning_rate: 0.0010
# Epoch 9/30
# 1936/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8272 - loss: 0.4534
# Epoch 9: val_loss did not improve from 0.42092
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8265 - loss: 0.4497 - val_accuracy: 0.8175 - val_loss: 0.4377 - learning_rate: 0.0010
# Epoch 10/30
# 1942/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8284 - loss: 0.4436
# Epoch 10: val_loss did not improve from 0.42092
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8284 - loss: 0.4411 - val_accuracy: 0.8240 - val_loss: 0.4251 - learning_rate: 0.0010
# Epoch 11/30
# 1939/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8286 - loss: 0.4369
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_loss did not improve from 0.42092
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8310 - loss: 0.4333 - val_accuracy: 0.8240 - val_loss: 0.4236 - learning_rate: 0.0010
# Epoch 12/30
# 1932/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8352 - loss: 0.4237
# Epoch 12: val_loss improved from 0.42092 to 0.41038, saving model to ./best_model/model.weights.h5
#
# Epoch 12: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8367 - loss: 0.4174 - val_accuracy: 0.8351 - val_loss: 0.4104 - learning_rate: 5.0000e-04
# Epoch 13/30
# 1935/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8419 - loss: 0.4072
# Epoch 13: val_loss improved from 0.41038 to 0.40938, saving model to ./best_model/model.weights.h5
#
# Epoch 13: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8428 - loss: 0.4032 - val_accuracy: 0.8312 - val_loss: 0.4094 - learning_rate: 5.0000e-04
# Epoch 14/30
# 1935/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8466 - loss: 0.3963
# Epoch 14: val_loss improved from 0.40938 to 0.38679, saving model to ./best_model/model.weights.h5
#
# Epoch 14: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8470 - loss: 0.3951 - val_accuracy: 0.8459 - val_loss: 0.3868 - learning_rate: 5.0000e-04
# Epoch 15/30
# 1938/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8517 - loss: 0.3903
# Epoch 15: val_loss did not improve from 0.38679
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8514 - loss: 0.3873 - val_accuracy: 0.8396 - val_loss: 0.3960 - learning_rate: 5.0000e-04
# Epoch 16/30
# 1940/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8486 - loss: 0.3885
# Epoch 16: val_loss improved from 0.38679 to 0.37698, saving model to ./best_model/model.weights.h5
#
# Epoch 16: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8507 - loss: 0.3816 - val_accuracy: 0.8536 - val_loss: 0.3770 - learning_rate: 5.0000e-04
# Epoch 17/30
# 1937/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8524 - loss: 0.3785
# Epoch 17: val_loss did not improve from 0.37698
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8531 - loss: 0.3781 - val_accuracy: 0.8486 - val_loss: 0.3835 - learning_rate: 5.0000e-04
# Epoch 18/30
# 1927/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8549 - loss: 0.3731
# Epoch 18: val_loss improved from 0.37698 to 0.36972, saving model to ./best_model/model.weights.h5
#
# Epoch 18: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8562 - loss: 0.3688 - val_accuracy: 0.8567 - val_loss: 0.3697 - learning_rate: 5.0000e-04
# Epoch 19/30
# 1934/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8571 - loss: 0.3708
# Epoch 19: val_loss improved from 0.36972 to 0.36300, saving model to ./best_model/model.weights.h5
#
# Epoch 19: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8589 - loss: 0.3670 - val_accuracy: 0.8579 - val_loss: 0.3630 - learning_rate: 5.0000e-04
# Epoch 20/30
# 1931/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8600 - loss: 0.3697
# Epoch 20: val_loss did not improve from 0.36300
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8609 - loss: 0.3653 - val_accuracy: 0.8585 - val_loss: 0.3665 - learning_rate: 5.0000e-04
# Epoch 21/30
# 1931/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8579 - loss: 0.3657
# Epoch 21: val_loss improved from 0.36300 to 0.36297, saving model to ./best_model/model.weights.h5
#
# Epoch 21: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8589 - loss: 0.3620 - val_accuracy: 0.8591 - val_loss: 0.3630 - learning_rate: 5.0000e-04
# Epoch 22/30
# 1937/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8622 - loss: 0.3569
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 22: val_loss did not improve from 0.36297
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8620 - loss: 0.3533 - val_accuracy: 0.8609 - val_loss: 0.3632 - learning_rate: 5.0000e-04
# Epoch 23/30
# 1932/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8649 - loss: 0.3516
# Epoch 23: val_loss improved from 0.36297 to 0.35884, saving model to ./best_model/model.weights.h5
#
# Epoch 23: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8681 - loss: 0.3420 - val_accuracy: 0.8611 - val_loss: 0.3588 - learning_rate: 2.5000e-04
# Epoch 24/30
# 1928/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8709 - loss: 0.3406
# Epoch 24: val_loss improved from 0.35884 to 0.34630, saving model to ./best_model/model.weights.h5
#
# Epoch 24: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8716 - loss: 0.3340 - val_accuracy: 0.8663 - val_loss: 0.3463 - learning_rate: 2.5000e-04
# Epoch 25/30
# 1927/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8679 - loss: 0.3386
# Epoch 25: val_loss did not improve from 0.34630
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8704 - loss: 0.3337 - val_accuracy: 0.8663 - val_loss: 0.3476 - learning_rate: 2.5000e-04
# Epoch 26/30
# 1926/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8723 - loss: 0.3265
# Epoch 26: val_loss improved from 0.34630 to 0.34480, saving model to ./best_model/model.weights.h5
#
# Epoch 26: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8752 - loss: 0.3244 - val_accuracy: 0.8675 - val_loss: 0.3448 - learning_rate: 2.5000e-04
# Epoch 27/30
# 1932/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8741 - loss: 0.3278
# Epoch 27: val_loss improved from 0.34480 to 0.34212, saving model to ./best_model/model.weights.h5
#
# Epoch 27: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8755 - loss: 0.3225 - val_accuracy: 0.8689 - val_loss: 0.3421 - learning_rate: 2.5000e-04
# Epoch 28/30
# 1938/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8762 - loss: 0.3181
# Epoch 28: val_loss improved from 0.34212 to 0.33861, saving model to ./best_model/model.weights.h5
#
# Epoch 28: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8787 - loss: 0.3162 - val_accuracy: 0.8687 - val_loss: 0.3386 - learning_rate: 2.5000e-04
# Epoch 29/30
# 1942/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8788 - loss: 0.3203
# Epoch 29: val_loss improved from 0.33861 to 0.33330, saving model to ./best_model/model.weights.h5
#
# Epoch 29: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8800 - loss: 0.3159 - val_accuracy: 0.8746 - val_loss: 0.3333 - learning_rate: 2.5000e-04
# Epoch 30/30
# 1939/1943 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8788 - loss: 0.3170
# Epoch 30: val_loss improved from 0.33330 to 0.33035, saving model to ./best_model/model.weights.h5
#
# Epoch 30: finished saving model to ./best_model/model.weights.h5
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8815 - loss: 0.3095 - val_accuracy: 0.8761 - val_loss: 0.3303 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 30.
#
#  Training complete!

# %% [markdown]
# ---
# ## 📈 Step 6: Evaluation

# %% [markdown]
# ### 6.1 Load Best Weights & Predict

# %%
model.load_weights('./best_model/model.weights.h5')
print("Loaded best model weights.")

# Predict on test set
y_pred_probs = model.predict(test_ds, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# Loaded best model weights.
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step

# %% [markdown]
# ### 6.2 Classification Report

# %%
target_names = sentiment_encoder.classes_.tolist()
print("\n" + "=" * 60)
print("CLASSIFICATION REPORT")
print("=" * 60)
print(classification_report(y_test, y_pred, target_names=target_names, digits=4))

overall_acc = accuracy_score(y_test, y_pred)
macro_f1 = f1_score(y_test, y_pred, average='macro')
print(f"Overall Accuracy: {overall_acc:.4f}")
print(f"Macro F1-Score:   {macro_f1:.4f}")
# Out:
# ============================================================
# CLASSIFICATION REPORT
# ============================================================
#               precision    recall  f1-score   support
#
#     Negative     0.9144    0.8896    0.9018      2700
#      Neutral     0.7500    0.8637    0.8029      1365
#     Positive     0.9244    0.8767    0.8999      2595
#
#     accuracy                         0.8793      6660
#    macro avg     0.8629    0.8767    0.8682      6660
# weighted avg     0.8846    0.8793    0.8808      6660
#
# Overall Accuracy: 0.8793
# Macro F1-Score:   0.8682

# %% [markdown]
# ### 6.3a Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues',
    xticklabels=target_names, yticklabels=target_names,
    linewidths=0.5, linecolor='gray', ax=ax
)
ax.set_xlabel('Predicted', fontsize=13)
ax.set_ylabel('Actual', fontsize=13)
ax.set_title('Confusion Matrix — Test Set', fontsize=15, fontweight='bold')
plt.tight_layout()
os.makedirs('loss_figure', exist_ok=True)
plt.savefig('loss_figure/confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()
print("Saved: loss_figure/confusion_matrix.png")
# Out:
# Saved: loss_figure/confusion_matrix.png

# %% [markdown]
# ### 6.3b Domain-Split Classification Report (Table 2 by domain/topic)

# %%
test_topic_names = topic_encoder.inverse_transform(topic_test)   # ground-truth, same order as y_test/y_pred
domain = np.where(test_topic_names == 'hotel', 'hotel-review', 'social-media')

print("Test set domain sizes:", {d: int((domain==d).sum()) for d in ['social-media','hotel-review']})

domain_rows = []
for d in ['social-media', 'hotel-review']:
    mask = domain == d
    print(f"\n{'='*60}\nDOMAIN: {d} (n={mask.sum()})\n{'='*60}")
    print(classification_report(y_test[mask], y_pred[mask], target_names=target_names, digits=4))
    domain_rows.append({'domain': d, 'n': int(mask.sum()),
                         'accuracy': accuracy_score(y_test[mask], y_pred[mask]),
                         'macro_f1': f1_score(y_test[mask], y_pred[mask], average='macro')})
pd.DataFrame(domain_rows).to_csv('./artifacts/table2_by_domain.csv', index=False)

# Per-topic breakdown (13 topics) — đủ mẫu vì domain nhỏ nhất cũng ~350-400/topic
per_topic_rows = []
for t in topic_encoder.classes_:
    mask = test_topic_names == t
    if mask.sum() == 0: continue
    per_topic_rows.append({'topic': t, 'n': int(mask.sum()),
                            'accuracy': accuracy_score(y_test[mask], y_pred[mask]),
                            'macro_f1': f1_score(y_test[mask], y_pred[mask], average='macro')})
per_topic_df = pd.DataFrame(per_topic_rows).sort_values('n', ascending=False)
print(per_topic_df.to_string(index=False))
per_topic_df.to_csv('./artifacts/table2_by_topic.csv', index=False)
# Out:
# Test set domain sizes: {'social-media': 3169, 'hotel-review': 3491}
#
# ============================================================
# DOMAIN: social-media (n=3169)
# ============================================================
#               precision    recall  f1-score   support
#
#     Negative     0.8748    0.8113    0.8418      1102
#      Neutral     0.7912    0.9112    0.8470      1239
#     Positive     0.8319    0.7234    0.7739       828
#
#     accuracy                         0.8274      3169
#    macro avg     0.8326    0.8153    0.8209      3169
# weighted avg     0.8309    0.8274    0.8261      3169
#
#
# ============================================================
# DOMAIN: hotel-review (n=3491)
# ============================================================
#               precision    recall  f1-score   support
#
#     Negative     0.9396    0.9437    0.9416      1598
#      Neutral     0.3448    0.3968    0.3690       126
#     Positive     0.9627    0.9485    0.9555      1767
#
#     accuracy                         0.9264      3491
#    macro avg     0.7490    0.7630    0.7554      3491
# weighted avg     0.9298    0.9264    0.9280      3491
#
#             topic    n  accuracy  macro_f1
#             hotel 3491  0.926382  0.755384
#           Verizon  310  0.822581  0.810236
#   johnson&johnson  307  0.895765  0.868380
# League Of Legends  304  0.802632  0.798277
#            Nvidia  299  0.765886  0.754154
#         Microsoft  295  0.874576  0.868559
#            Amazon  281  0.854093  0.774082
#         HomeDepot  255  0.870588  0.858190
# PlayStation5(PS5)  240  0.783333  0.748069
#             Apple  239  0.753138  0.659396
#            Google  227  0.850220  0.828138
#          Facebook  209  0.803828  0.737170
#     Xbox(Xseries)  203  0.837438  0.825980

# %% [markdown]
# ### 6.4 Training History (Loss & Accuracy Curves)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Loss curve
axes[0].plot(history.history['loss'], label='Train Loss', linewidth=2, color='#e74c3c')
axes[0].plot(history.history['val_loss'], label='Val Loss', linewidth=2, color='#3498db')
axes[0].set_title('Loss per Epoch', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid(alpha=0.3)

# Accuracy curve
axes[1].plot(history.history['accuracy'], label='Train Accuracy', linewidth=2, color='#e74c3c')
axes[1].plot(history.history['val_accuracy'], label='Val Accuracy', linewidth=2, color='#3498db')
axes[1].set_title('Accuracy per Epoch', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig('loss_figure/training_history.png', dpi=150, bbox_inches='tight')
plt.show()
print("Saved: loss_figure/training_history.png")
# Out:
# Saved: loss_figure/training_history.png

# %% [markdown]
# ---
# ## 📐 Step 6.5: Baseline Comparison (Table 3)
#
# The full model (RoBERTa embeddings + topic embedding + BatchNorm + skip-connection head) is only a
# meaningful result if it is compared against baselines that either (a) use no training at all, or
# (b) receive progressively more of the same input. Five points of comparison:
#
# | # | Baseline | Text feature | Topic feature | Trained? |
# |---|----------|-------------|----------------|----------|
# | A | Zero-shot cardiffnlp RoBERTa head | raw tweet (model's own preprocessing) | — | No |
# | B | TF-IDF + Logistic Regression | `clean_text` | — | Yes |
# | C | TF-IDF + one-hot topic + Logistic Regression | `clean_text` | one-hot(12), auto-predicted (Step 3.5) | Yes |
# | D | RoBERTa mean-pooled embeddings + Logistic Regression | 768-dim embedding | — | Yes (LR only) |
# | E | TF-IDF (light cleaning) + Logistic Regression | `clean_text_light` | — | Yes |
#
# Baseline **C** is the only one that receives the same (text, topic) input as the main model —
# including the same auto-predicted topic, not the ground-truth label — so it is the one that actually
# tests whether the Keras head's extra depth/BatchNorm/skip-connection earns its keep over a linear
# model given identical features.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from scipy.sparse import hstack

baseline_results = []

def record_baseline(name, y_true, y_pred, notes=""):
    acc = accuracy_score(y_true, y_pred)
    f1m = f1_score(y_true, y_pred, average='macro')
    baseline_results.append({'model': name, 'accuracy': acc, 'macro_f1': f1m, 'notes': notes})
    print(f"[{name}] accuracy={acc:.4f}  macro_f1={f1m:.4f}  {notes}")
    return acc, f1m

# %% [markdown]
# ### Baseline A — Zero-shot cardiffnlp RoBERTa Sentiment Head (no training)
#
# Uses the pretrained classification head that ships with `cardiffnlp/twitter-roberta-base-sentiment-latest`
# directly — no fine-tuning, no Keras head. This is the "for free" floor: any trained model on this
# dataset should clear it by a meaningful margin. Text is preprocessed with the model card's own
# convention (`@user`, `http`) rather than the notebook's aggressive `clean_text()`, since that is
# what the checkpoint was tuned on.

# %%
# --- Baseline A: Zero-shot cardiffnlp RoBERTa sentiment head (no training) ---
from transformers import AutoModelForSequenceClassification

def roberta_card_preprocess(text):
    """cardiffnlp's own preprocessing convention (not our clean_text)."""
    if not isinstance(text, str):
        return ""
    new_tokens = []
    for tok in text.split(' '):
        tok = '@user' if tok.startswith('@') and len(tok) > 1 else tok
        tok = 'http' if tok.startswith('http') else tok
        new_tokens.append(tok)
    return ' '.join(new_tokens)

zero_shot_model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME)
zero_shot_model.to(DEVICE)
zero_shot_model.eval()

id2label = {int(k): v.lower() for k, v in zero_shot_model.config.id2label.items()}
print(f"Zero-shot model label map: {id2label}")

zero_shot_preds = []
zs_batch_size = EMBED_BATCH_SIZE
zs_texts = [roberta_card_preprocess(t) for t in X_test_raw]

for i in range(0, len(zs_texts), zs_batch_size):
    batch = zs_texts[i:i + zs_batch_size]
    encoding = tokenizer(batch, max_length=MAX_LEN, padding='max_length', truncation=True, return_tensors='pt')
    input_ids = encoding['input_ids'].to(DEVICE)
    attention_mask = encoding['attention_mask'].to(DEVICE)
    with torch.no_grad():
        logits = zero_shot_model(input_ids=input_ids, attention_mask=attention_mask).logits
    batch_pred_ids = torch.argmax(logits, dim=1).cpu().numpy()
    zero_shot_preds.extend(batch_pred_ids)
    if (i // zs_batch_size) % 20 == 0:
        print(f"  Zero-shot inference {min(i + zs_batch_size, len(zs_texts))}/{len(zs_texts)}...")

# Map the checkpoint's own label ids -> our sentiment_encoder's label ids via the class names
zs_label_names = [id2label[p] for p in zero_shot_preds]
our_class_lookup = {c.lower(): idx for idx, c in enumerate(sentiment_encoder.classes_)}
y_pred_zero_shot = np.array([our_class_lookup[name] for name in zs_label_names])

del zero_shot_model
if torch.cuda.is_available():
    torch.cuda.empty_cache()

record_baseline('A: Zero-shot RoBERTa head', y_test, y_pred_zero_shot, notes="no training, model's own head")
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-sentiment-latest
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.bias   | UNEXPECTED |  |
# roberta.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Zero-shot model label map: {0: 'negative', 1: 'neutral', 2: 'positive'}
#   Zero-shot inference 64/6660...
#   Zero-shot inference 1344/6660...
#   Zero-shot inference 2624/6660...
#   Zero-shot inference 3904/6660...
#   Zero-shot inference 5184/6660...
#   Zero-shot inference 6464/6660...
# [A: Zero-shot RoBERTa head] accuracy=0.6634  macro_f1=0.6256  no training, model's own head
# (0.6633633633633633, 0.6256075159196062)

# %% [markdown]
# ### Baseline B — TF-IDF + Logistic Regression (text only)
#
# Classic sparse bag-of-words baseline. Fit on `clean_text` (the same text the main model's
# embeddings were extracted from), no topic information.

# %%
# --- Baseline B: TF-IDF + Logistic Regression (text only) ---
tfidf_vectorizer = TfidfVectorizer(max_features=20000, ngram_range=(1, 2), min_df=2)
Xtr_tfidf = tfidf_vectorizer.fit_transform(X_train_text)
Xte_tfidf = tfidf_vectorizer.transform(X_test_text)

lr_tfidf = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=SEED)
lr_tfidf.fit(Xtr_tfidf, y_train)
y_pred_tfidf = lr_tfidf.predict(Xte_tfidf)

record_baseline('B: TF-IDF + LogisticRegression', y_test, y_pred_tfidf, notes=f"vocab={len(tfidf_vectorizer.vocabulary_)}")
# Out:
# [B: TF-IDF + LogisticRegression] accuracy=0.8595  macro_f1=0.8486  vocab=20000
# (0.8594594594594595, 0.8486073528918118)

# %% [markdown]
# ### Baseline C — TF-IDF + One-Hot Topic + Logistic Regression
#
# The only baseline that receives **exactly the same (text, topic) input** as the main dual-input
# model — including using the Step 3.5 auto-predicted topic rather than the ground-truth label. If the
# deep head in Step 4 doesn't beat this by a clear margin, the extra architecture isn't earning its
# complexity.

# %%
# --- Baseline C: TF-IDF + One-Hot Topic + Logistic Regression ---
# Uses topic_*_pred (Step 3.5), the same auto-predicted topic the main model is trained on —
# not the ground-truth topic — so this stays a fair "same input as the main model" comparison.
topic_ohe = OneHotEncoder(handle_unknown='ignore')
topic_train_oh = topic_ohe.fit_transform(topic_train_pred.reshape(-1, 1))
topic_test_oh = topic_ohe.transform(topic_test_pred.reshape(-1, 1))

Xtr_combined = hstack([Xtr_tfidf, topic_train_oh])
Xte_combined = hstack([Xte_tfidf, topic_test_oh])

lr_combined = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=SEED)
lr_combined.fit(Xtr_combined, y_train)
y_pred_combined = lr_combined.predict(Xte_combined)

record_baseline('C: TF-IDF + topic one-hot + LogisticRegression', y_test, y_pred_combined,
                notes="same (text, predicted-topic) input as the main model")
# Out:
# [C: TF-IDF + topic one-hot + LogisticRegression] accuracy=0.8547  macro_f1=0.8443  same (text, predicted-topic) input as the main model
# (0.8546546546546546, 0.8443137149805174)

# %% [markdown]
# ### Baseline D — RoBERTa Embeddings + Logistic Regression
#
# Uses the exact same 768-dim mean-pooled embeddings extracted in Step 3 (no topic), fed to a linear
# classifier instead of the Keras head. `StandardScaler` + `max_iter=2000` are required — the default
# `lbfgs` solver at `max_iter=100` does not reliably converge on 768-dimensional dense features.

# %%
# --- Baseline D: RoBERTa Embeddings + Logistic Regression ---
emb_scaler = StandardScaler()
Xtr_emb_scaled = emb_scaler.fit_transform(train_embeddings)
Xte_emb_scaled = emb_scaler.transform(test_embeddings)

lr_emb = LogisticRegression(max_iter=2000, class_weight='balanced', random_state=SEED)
lr_emb.fit(Xtr_emb_scaled, y_train)
y_pred_emb = lr_emb.predict(Xte_emb_scaled)

record_baseline('D: RoBERTa embeddings + LogisticRegression', y_test, y_pred_emb,
                notes="StandardScaler + max_iter=2000 to ensure convergence")
# Out:
# [D: RoBERTa embeddings + LogisticRegression] accuracy=0.8116  macro_f1=0.7949  StandardScaler + max_iter=2000 to ensure convergence
# (0.8115615615615616, 0.7948808012391559)

# %% [markdown]
# ### Baseline E — Cleaning Variant Delta (light cleaning vs. main cleaning)
#
# Same TF-IDF + Logistic Regression pipeline as Baseline B, but fit on `clean_text_light` (keeps
# digits and hashtag words) instead of `clean_text`. The accuracy/F1 delta versus Baseline B
# quantifies how much sentiment signal the aggressive cleaning in Step 2.2 throws away.

# %%
# --- Baseline E: Cleaning Variant Delta (light cleaning vs. main cleaning) ---
X_light = df['clean_text_light'].values

X_train_light, X_temp_light, y_train_chk, y_temp_chk = train_test_split(
    X_light, y_sentiment, test_size=0.30, stratify=y_sentiment, random_state=SEED
)
X_val_light, X_test_light, y_val_chk, y_test_chk = train_test_split(
    X_temp_light, y_temp_chk, test_size=0.50, stratify=y_temp_chk, random_state=SEED
)
assert np.array_equal(y_train_chk, y_train) and np.array_equal(y_test_chk, y_test), \
    "Light-cleaning split does not align with the main split — cannot compare fairly."

tfidf_light = TfidfVectorizer(max_features=20000, ngram_range=(1, 2), min_df=2)
Xtr_light_tfidf = tfidf_light.fit_transform(X_train_light)
Xte_light_tfidf = tfidf_light.transform(X_test_light)

lr_light = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=SEED)
lr_light.fit(Xtr_light_tfidf, y_train)
y_pred_light = lr_light.predict(Xte_light_tfidf)

acc_light, f1_light = record_baseline('E: TF-IDF (light cleaning) + LogisticRegression', y_test, y_pred_light,
                                       notes="keeps digits & hashtag words")

acc_b = baseline_results[1]['accuracy']  # Baseline B
f1_b = baseline_results[1]['macro_f1']
print(f"\nCleaning delta vs. Baseline B: accuracy {acc_light - acc_b:+.4f}, macro_f1 {f1_light - f1_b:+.4f}")
# Out:
# [E: TF-IDF (light cleaning) + LogisticRegression] accuracy=0.8601  macro_f1=0.8496  keeps digits & hashtag words
#
# Cleaning delta vs. Baseline B: accuracy +0.0006, macro_f1 +0.0010

# %%
# --- Table 3 — Full Comparison Summary ---
baseline_results.append({
    'model': 'Main model (RoBERTa emb + topic + BN + skip head)',
    'accuracy': overall_acc,
    'macro_f1': macro_f1,
    'notes': 'trained head, Step 4-6'
})

baseline_table = pd.DataFrame(baseline_results).sort_values('macro_f1', ascending=False).reset_index(drop=True)
print("=" * 80)
print("TABLE 3 — Baseline & Main Model Comparison (Test Set)")
print("=" * 80)
print(baseline_table.to_string(index=False, float_format=lambda x: f"{x:.4f}"))
baseline_table.to_csv('./artifacts/baseline_comparison_table3.csv', index=False)
print("\nSaved: ./artifacts/baseline_comparison_table3.csv")
# Out:
# ================================================================================
# TABLE 3 — Baseline & Main Model Comparison (Test Set)
# ================================================================================
#                                             model  accuracy  macro_f1                                                notes
# Main model (RoBERTa emb + topic + BN + skip head)    0.8793    0.8682                               trained head, Step 4-6
#   E: TF-IDF (light cleaning) + LogisticRegression    0.8601    0.8496                         keeps digits & hashtag words
#                    B: TF-IDF + LogisticRegression    0.8595    0.8486                                          vocab=20000
#    C: TF-IDF + topic one-hot + LogisticRegression    0.8547    0.8443 same (text, predicted-topic) input as the main model
#        D: RoBERTa embeddings + LogisticRegression    0.8116    0.7949 StandardScaler + max_iter=2000 to ensure convergence
#                         A: Zero-shot RoBERTa head    0.6634    0.6256                        no training, model's own head
#
# Saved: ./artifacts/baseline_comparison_table3.csv

# %% [markdown]
# ---
# ## 🧪 Step 6.6: Ablation Study — Topic Branch / Skip Connection / BatchNorm
#
# Four architecture variants, each trained fresh at two epoch budgets (15 and 30) across 5 random
# seeds, to report **mean ± std** test accuracy / macro-F1 per (variant, epoch-budget) cell instead
# of a single-run number. This is what actually lets us claim which component matters most — a single
# training run cannot distinguish "this component helps" from "this particular seed got lucky."
#
# ⚠️ **Runtime note:** this is 4 variants × 2 epoch budgets × 5 seeds = 40 training runs (each fast —
# head-only training on cached embeddings, no RoBERTa forward pass). Reduce `N_SEEDS` below for a
# quick smoke test.

# %%
def build_model_ablation(variant='full', roberta_dim=768, num_topics=12, num_classes=3,
                          topic_emb_dim=32, dropout_rate=0.4):
    """
    variant:
      'full'      - topic branch + skip connection + BatchNorm (identical to build_model())
      'no_topic'  - topic embedding output is multiplied by 0 before fusion (kept in the graph so
                    the model still accepts the same {'text_embedding','topic_id'} input dict, but
                    contributes nothing to the forward pass and receives zero gradient)
      'no_skip'   - remove the skip connection (concat[x, combined] -> just x)
      'no_bn'     - remove all BatchNormalization layers
    """
    assert variant in ('full', 'no_topic', 'no_skip', 'no_bn')
    use_topic = variant != 'no_topic'
    use_skip = variant != 'no_skip'
    use_bn = variant != 'no_bn'

    text_embedding = tf.keras.Input(shape=(roberta_dim,), dtype=tf.float32, name='text_embedding')
    topic_id = tf.keras.Input(shape=(1,), dtype=tf.int32, name='topic_id')

    text_vec = tf.keras.layers.BatchNormalization(name='text_bn')(text_embedding) if use_bn else text_embedding
    text_vec = tf.keras.layers.Dropout(dropout_rate, name='text_dropout')(text_vec)

    topic_vec = tf.keras.layers.Embedding(input_dim=num_topics + 1, output_dim=topic_emb_dim,
                                           name='topic_embedding')(topic_id)
    topic_vec = tf.keras.layers.Flatten(name='topic_flatten')(topic_vec)
    if not use_topic:
        topic_vec = tf.keras.layers.Lambda(lambda t: t * 0.0, name='topic_zero_gate')(topic_vec)

    combined = tf.keras.layers.Concatenate(name='fusion')([text_vec, topic_vec])
    x = tf.keras.layers.Dense(512, activation='relu', name='dense_512')(combined)
    x = tf.keras.layers.BatchNormalization(name='bn_512')(x) if use_bn else x
    x = tf.keras.layers.Dropout(dropout_rate, name='dropout_512')(x)
    x = tf.keras.layers.Dense(256, activation='relu', name='dense_256')(x)
    if use_skip:
        x = tf.keras.layers.Concatenate(name='skip_connection')([x, combined])
    x = tf.keras.layers.Dense(256, activation='relu', name='dense_256b')(x)
    x = tf.keras.layers.BatchNormalization(name='bn_256')(x) if use_bn else x
    x = tf.keras.layers.Dropout(dropout_rate, name='dropout_256')(x)
    x = tf.keras.layers.Dense(64, activation='relu', name='dense_64')(x)
    output = tf.keras.layers.Dense(num_classes, activation='softmax', name='output')(x)

    return tf.keras.Model(inputs=[text_embedding, topic_id], outputs=output, name=f'Ablation_{variant}')

# %%
# --- Ablation Runner (multi-seed, multi-epoch-budget) ---
ABLATION_VARIANTS = ['full', 'no_topic', 'no_skip', 'no_bn']
EPOCH_BUDGETS = [15, 30]
N_SEEDS = 5  # reduce to 1-2 for a quick smoke test

ablation_rows = []
ablation_ckpt_dir = './ablation_ckpt'
os.makedirs(ablation_ckpt_dir, exist_ok=True)

for variant in ABLATION_VARIANTS:
    for epochs in EPOCH_BUDGETS:
        patience = 4 if epochs == 15 else 5  # shorter budget -> proportionally shorter patience
        for seed in range(N_SEEDS):
            tf.random.set_seed(seed)
            np.random.seed(seed)

            run_model = build_model_ablation(variant, ROBERTA_DIM, NUM_TOPICS, NUM_CLASSES, TOPIC_EMB_DIM, DROPOUT_RATE)
            run_model.compile(
                optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=0.01),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                metrics=['accuracy']
            )

            ckpt_path = f'{ablation_ckpt_dir}/{variant}_ep{epochs}_seed{seed}.weights.h5'
            run_callbacks = make_callbacks(patience=patience, checkpoint_path=ckpt_path)

            run_model.fit(
                train_ds, validation_data=val_ds, epochs=epochs,
                class_weight=class_weight_dict, callbacks=run_callbacks, verbose=0
            )
            run_model.load_weights(ckpt_path)

            y_probs = run_model.predict(test_ds, verbose=0)
            y_hat = np.argmax(y_probs, axis=1)
            acc = accuracy_score(y_test, y_hat)
            f1m = f1_score(y_test, y_hat, average='macro')

            ablation_rows.append({'variant': variant, 'epochs': epochs, 'seed': seed,
                                   'accuracy': acc, 'macro_f1': f1m})
            print(f"[{variant} | epochs={epochs} | seed={seed}] acc={acc:.4f} macro_f1={f1m:.4f}")

            del run_model
            tf.keras.backend.clear_session()

# Restore the global seed for anything that runs after the ablation study
tf.random.set_seed(SEED)
np.random.seed(SEED)

ablation_df = pd.DataFrame(ablation_rows)
ablation_df.to_csv('./artifacts/ablation_raw_results.csv', index=False)
print(f"\nSaved {len(ablation_df)} raw ablation runs -> ./artifacts/ablation_raw_results.csv")
# Out:
# Epoch 1: val_loss improved from None to 0.49428, saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 2: val_loss did not improve from 0.49428
#
# Epoch 3: val_loss improved from 0.49428 to 0.46299, saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 3: finished saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 4: val_loss did not improve from 0.46299
#
# Epoch 5: val_loss did not improve from 0.46299
#
# Epoch 6: val_loss improved from 0.46299 to 0.45933, saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 7: val_loss improved from 0.45933 to 0.42094, saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 7: finished saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 8: val_loss did not improve from 0.42094
#
# Epoch 9: val_loss did not improve from 0.42094
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 10: val_loss did not improve from 0.42094
#
# Epoch 11: val_loss improved from 0.42094 to 0.40732, saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 11: finished saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 12: val_loss improved from 0.40732 to 0.40489, saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 12: finished saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 13: val_loss improved from 0.40489 to 0.39228, saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 13: finished saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 14: val_loss did not improve from 0.39228
#
# Epoch 15: val_loss improved from 0.39228 to 0.37534, saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
#
# Epoch 15: finished saving model to ./ablation_ckpt/full_ep15_seed0.weights.h5
# Restoring model weights from the end of the best epoch: 15.
# [full | epochs=15 | seed=0] acc=0.8527 macro_f1=0.8379
#
# Epoch 1: val_loss improved from None to 0.49858, saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 2: val_loss improved from 0.49858 to 0.48062, saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 3: val_loss improved from 0.48062 to 0.46928, saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 3: finished saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 4: val_loss improved from 0.46928 to 0.45883, saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 4: finished saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 5: val_loss improved from 0.45883 to 0.44730, saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 5: finished saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 6: val_loss improved from 0.44730 to 0.43563, saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 7: val_loss improved from 0.43563 to 0.43197, saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 7: finished saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 8: val_loss improved from 0.43197 to 0.42667, saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 8: finished saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 9: val_loss did not improve from 0.42667
#
# Epoch 10: val_loss improved from 0.42667 to 0.42178, saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 10: finished saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 11: val_loss improved from 0.42178 to 0.40989, saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 11: finished saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 12: val_loss improved from 0.40989 to 0.40530, saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 12: finished saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 13: val_loss did not improve from 0.40530
#
# Epoch 14: val_loss did not improve from 0.40530
#
# Epoch 15: val_loss improved from 0.40530 to 0.38787, saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
#
# Epoch 15: finished saving model to ./ablation_ckpt/full_ep15_seed1.weights.h5
# Restoring model weights from the end of the best epoch: 15.
# [full | epochs=15 | seed=1] acc=0.8452 macro_f1=0.8299
#
# Epoch 1: val_loss improved from None to 0.48002, saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 2: val_loss improved from 0.48002 to 0.46937, saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 3: val_loss improved from 0.46937 to 0.46546, saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 3: finished saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 4: val_loss improved from 0.46546 to 0.44741, saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 4: finished saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 5: val_loss did not improve from 0.44741
#
# Epoch 6: val_loss improved from 0.44741 to 0.43956, saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 7: val_loss improved from 0.43956 to 0.43689, saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 7: finished saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 8: val_loss improved from 0.43689 to 0.43677, saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 8: finished saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 9: val_loss did not improve from 0.43677
#
# Epoch 10: val_loss improved from 0.43677 to 0.41270, saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 10: finished saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 11: val_loss improved from 0.41270 to 0.40720, saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 11: finished saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 12: val_loss did not improve from 0.40720
#
# Epoch 13: val_loss improved from 0.40720 to 0.40560, saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 13: finished saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 14: val_loss did not improve from 0.40560
#
# Epoch 15: val_loss improved from 0.40560 to 0.39335, saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
#
# Epoch 15: finished saving model to ./ablation_ckpt/full_ep15_seed2.weights.h5
# Restoring model weights from the end of the best epoch: 15.
# [full | epochs=15 | seed=2] acc=0.8420 macro_f1=0.8267
#
# Epoch 1: val_loss improved from None to 0.53688, saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 2: val_loss improved from 0.53688 to 0.49401, saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 3: val_loss improved from 0.49401 to 0.44665, saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 3: finished saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 4: val_loss did not improve from 0.44665
#
# Epoch 5: val_loss did not improve from 0.44665
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 6: val_loss did not improve from 0.44665
#
# Epoch 7: val_loss improved from 0.44665 to 0.43740, saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 7: finished saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 8: val_loss improved from 0.43740 to 0.41685, saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 8: finished saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 9: val_loss improved from 0.41685 to 0.40852, saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 9: finished saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 10: val_loss did not improve from 0.40852
#
# Epoch 11: val_loss improved from 0.40852 to 0.39814, saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 11: finished saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 12: val_loss did not improve from 0.39814
#
# Epoch 13: val_loss improved from 0.39814 to 0.39244, saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 13: finished saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 14: val_loss improved from 0.39244 to 0.38924, saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/full_ep15_seed3.weights.h5
#
# Epoch 15: val_loss did not improve from 0.38924
# Restoring model weights from the end of the best epoch: 14.
# [full | epochs=15 | seed=3] acc=0.8462 macro_f1=0.8327
#
# Epoch 1: val_loss improved from None to 0.50308, saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 2: val_loss improved from 0.50308 to 0.46798, saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 3: val_loss did not improve from 0.46798
#
# Epoch 4: val_loss improved from 0.46798 to 0.46636, saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 4: finished saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 5: val_loss did not improve from 0.46636
#
# Epoch 6: val_loss improved from 0.46636 to 0.44095, saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 7: val_loss improved from 0.44095 to 0.42833, saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 7: finished saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 8: val_loss did not improve from 0.42833
#
# Epoch 9: val_loss improved from 0.42833 to 0.42086, saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 9: finished saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 10: val_loss improved from 0.42086 to 0.41274, saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 10: finished saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 11: val_loss did not improve from 0.41274
#
# Epoch 12: val_loss improved from 0.41274 to 0.39957, saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 12: finished saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 13: val_loss improved from 0.39957 to 0.39769, saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 13: finished saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 14: val_loss improved from 0.39769 to 0.38994, saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/full_ep15_seed4.weights.h5
#
# Epoch 15: val_loss did not improve from 0.38994
# Restoring model weights from the end of the best epoch: 14.
# [full | epochs=15 | seed=4] acc=0.8450 macro_f1=0.8294
#
# Epoch 1: val_loss improved from None to 0.50229, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 2: val_loss improved from 0.50229 to 0.48166, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 3: val_loss did not improve from 0.48166
#
# Epoch 4: val_loss improved from 0.48166 to 0.46558, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 4: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 5: val_loss improved from 0.46558 to 0.46016, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 5: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 6: val_loss improved from 0.46016 to 0.45990, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 7: val_loss improved from 0.45990 to 0.43922, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 7: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 8: val_loss improved from 0.43922 to 0.42465, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 8: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 9: val_loss improved from 0.42465 to 0.42411, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 9: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 10: val_loss improved from 0.42411 to 0.41720, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 10: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 11: val_loss did not improve from 0.41720
#
# Epoch 12: val_loss improved from 0.41720 to 0.41526, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 12: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 13: val_loss improved from 0.41526 to 0.39829, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 13: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 14: val_loss did not improve from 0.39829
#
# Epoch 15: val_loss did not improve from 0.39829
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 16: val_loss did not improve from 0.39829
#
# Epoch 17: val_loss improved from 0.39829 to 0.37947, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 17: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 18: val_loss improved from 0.37947 to 0.37054, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 18: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 19: val_loss improved from 0.37054 to 0.36346, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 19: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 20: val_loss did not improve from 0.36346
#
# Epoch 21: val_loss did not improve from 0.36346
#
# Epoch 22: val_loss improved from 0.36346 to 0.35235, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 22: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 23: val_loss improved from 0.35235 to 0.34826, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 23: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 24: val_loss improved from 0.34826 to 0.34693, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 24: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 25: val_loss improved from 0.34693 to 0.34243, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 25: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 26: val_loss did not improve from 0.34243
#
# Epoch 27: val_loss improved from 0.34243 to 0.33741, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 27: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 28: val_loss improved from 0.33741 to 0.33542, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 28: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 29: val_loss improved from 0.33542 to 0.33478, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 29: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 30: val_loss improved from 0.33478 to 0.32631, saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
#
# Epoch 30: finished saving model to ./ablation_ckpt/full_ep30_seed0.weights.h5
# Restoring model weights from the end of the best epoch: 30.
# [full | epochs=30 | seed=0] acc=0.8749 macro_f1=0.8625
#
# Epoch 1: val_loss improved from None to 0.54506, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 2: val_loss improved from 0.54506 to 0.46863, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 3: val_loss did not improve from 0.46863
#
# Epoch 4: val_loss improved from 0.46863 to 0.46225, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 4: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 5: val_loss improved from 0.46225 to 0.46207, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 5: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 6: val_loss improved from 0.46207 to 0.44111, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 7: val_loss did not improve from 0.44111
#
# Epoch 8: val_loss improved from 0.44111 to 0.43009, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 8: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 9: val_loss improved from 0.43009 to 0.42559, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 9: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 10: val_loss improved from 0.42559 to 0.41799, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 10: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 11: val_loss improved from 0.41799 to 0.41370, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 11: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 12: val_loss improved from 0.41370 to 0.41314, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 12: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 13: val_loss did not improve from 0.41314
#
# Epoch 14: val_loss improved from 0.41314 to 0.40574, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 15: val_loss improved from 0.40574 to 0.39635, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 15: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 16: val_loss did not improve from 0.39635
#
# Epoch 17: val_loss improved from 0.39635 to 0.39106, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 17: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 18: val_loss improved from 0.39106 to 0.38187, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 18: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 19: val_loss improved from 0.38187 to 0.38113, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 19: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 20: val_loss improved from 0.38113 to 0.36573, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 20: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 21: val_loss did not improve from 0.36573
#
# Epoch 22: val_loss did not improve from 0.36573
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 23: val_loss did not improve from 0.36573
#
# Epoch 24: val_loss improved from 0.36573 to 0.35564, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 24: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 25: val_loss improved from 0.35564 to 0.33912, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 25: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 26: val_loss did not improve from 0.33912
#
# Epoch 27: val_loss did not improve from 0.33912
#
# Epoch 28: val_loss improved from 0.33912 to 0.33452, saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 28: finished saving model to ./ablation_ckpt/full_ep30_seed1.weights.h5
#
# Epoch 29: val_loss did not improve from 0.33452
#
# Epoch 30: val_loss did not improve from 0.33452
# Restoring model weights from the end of the best epoch: 28.
# [full | epochs=30 | seed=1] acc=0.8746 macro_f1=0.8620
#
# Epoch 1: val_loss improved from None to 0.50763, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 2: val_loss improved from 0.50763 to 0.47602, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 3: val_loss improved from 0.47602 to 0.46090, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 3: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 4: val_loss did not improve from 0.46090
#
# Epoch 5: val_loss did not improve from 0.46090
#
# Epoch 6: val_loss improved from 0.46090 to 0.44627, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 7: val_loss did not improve from 0.44627
#
# Epoch 8: val_loss improved from 0.44627 to 0.43169, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 8: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 9: val_loss improved from 0.43169 to 0.41404, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 9: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 10: val_loss did not improve from 0.41404
#
# Epoch 11: val_loss did not improve from 0.41404
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 12: val_loss did not improve from 0.41404
#
# Epoch 13: val_loss improved from 0.41404 to 0.39627, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 13: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 14: val_loss improved from 0.39627 to 0.39231, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 15: val_loss improved from 0.39231 to 0.39180, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 15: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 16: val_loss improved from 0.39180 to 0.38709, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 16: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 17: val_loss improved from 0.38709 to 0.38070, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 17: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 18: val_loss improved from 0.38070 to 0.36996, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 18: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 19: val_loss improved from 0.36996 to 0.36479, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 19: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 20: val_loss improved from 0.36479 to 0.36037, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 20: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 21: val_loss did not improve from 0.36037
#
# Epoch 22: val_loss improved from 0.36037 to 0.35544, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 22: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 23: val_loss did not improve from 0.35544
#
# Epoch 24: val_loss improved from 0.35544 to 0.35435, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 24: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 25: val_loss improved from 0.35435 to 0.34896, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 25: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 26: val_loss did not improve from 0.34896
#
# Epoch 27: val_loss improved from 0.34896 to 0.33794, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 27: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 28: val_loss did not improve from 0.33794
#
# Epoch 29: val_loss did not improve from 0.33794
#
# Epoch 30: val_loss improved from 0.33794 to 0.33281, saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
#
# Epoch 30: finished saving model to ./ablation_ckpt/full_ep30_seed2.weights.h5
# Restoring model weights from the end of the best epoch: 30.
# [full | epochs=30 | seed=2] acc=0.8761 macro_f1=0.8645
#
# Epoch 1: val_loss improved from None to 0.48920, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 2: val_loss improved from 0.48920 to 0.47794, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 3: val_loss improved from 0.47794 to 0.47298, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 3: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 4: val_loss improved from 0.47298 to 0.43994, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 4: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 5: val_loss did not improve from 0.43994
#
# Epoch 6: val_loss did not improve from 0.43994
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 7: val_loss did not improve from 0.43994
#
# Epoch 8: val_loss improved from 0.43994 to 0.41934, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 8: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 9: val_loss improved from 0.41934 to 0.41080, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 9: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 10: val_loss did not improve from 0.41080
#
# Epoch 11: val_loss improved from 0.41080 to 0.40023, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 11: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 12: val_loss improved from 0.40023 to 0.39924, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 12: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 13: val_loss did not improve from 0.39924
#
# Epoch 14: val_loss improved from 0.39924 to 0.39918, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 15: val_loss improved from 0.39918 to 0.38884, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 15: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 16: val_loss improved from 0.38884 to 0.38599, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 16: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 17: val_loss improved from 0.38599 to 0.36884, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 17: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 18: val_loss did not improve from 0.36884
#
# Epoch 19: val_loss did not improve from 0.36884
#
# Epoch 20: val_loss improved from 0.36884 to 0.36533, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 20: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 21: val_loss improved from 0.36533 to 0.36227, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 21: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 22: val_loss did not improve from 0.36227
#
# Epoch 23: val_loss improved from 0.36227 to 0.35065, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 23: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 24: val_loss did not improve from 0.35065
#
# Epoch 25: val_loss improved from 0.35065 to 0.34709, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 25: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 26: val_loss improved from 0.34709 to 0.34297, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 26: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 27: val_loss did not improve from 0.34297
#
# Epoch 28: val_loss did not improve from 0.34297
#
# Epoch 29: val_loss improved from 0.34297 to 0.33596, saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 29: finished saving model to ./ablation_ckpt/full_ep30_seed3.weights.h5
#
# Epoch 30: val_loss did not improve from 0.33596
# Restoring model weights from the end of the best epoch: 29.
# [full | epochs=30 | seed=3] acc=0.8721 macro_f1=0.8596
#
# Epoch 1: val_loss improved from None to 0.53252, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 2: val_loss improved from 0.53252 to 0.48745, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 3: val_loss improved from 0.48745 to 0.46416, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 3: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 4: val_loss improved from 0.46416 to 0.44618, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 4: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 5: val_loss did not improve from 0.44618
#
# Epoch 6: val_loss improved from 0.44618 to 0.44418, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 7: val_loss did not improve from 0.44418
#
# Epoch 8: val_loss improved from 0.44418 to 0.43043, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 8: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 9: val_loss improved from 0.43043 to 0.42884, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 9: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 10: val_loss did not improve from 0.42884
#
# Epoch 11: val_loss improved from 0.42884 to 0.40969, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 11: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 12: val_loss did not improve from 0.40969
#
# Epoch 13: val_loss did not improve from 0.40969
#
# Epoch 14: val_loss improved from 0.40969 to 0.39832, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 15: val_loss did not improve from 0.39832
#
# Epoch 16: val_loss did not improve from 0.39832
#
# Epoch 17: val_loss improved from 0.39832 to 0.38643, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 17: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 18: val_loss did not improve from 0.38643
#
# Epoch 19: val_loss improved from 0.38643 to 0.38395, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 19: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 20: val_loss improved from 0.38395 to 0.37588, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 20: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 21: val_loss improved from 0.37588 to 0.37237, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 21: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 22: val_loss did not improve from 0.37237
#
# Epoch 23: val_loss did not improve from 0.37237
#
# Epoch 24: val_loss improved from 0.37237 to 0.36252, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 24: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 25: val_loss improved from 0.36252 to 0.35721, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 25: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 26: val_loss did not improve from 0.35721
#
# Epoch 27: val_loss did not improve from 0.35721
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 28: val_loss did not improve from 0.35721
#
# Epoch 29: val_loss improved from 0.35721 to 0.34511, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 29: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 30: val_loss improved from 0.34511 to 0.33639, saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
#
# Epoch 30: finished saving model to ./ablation_ckpt/full_ep30_seed4.weights.h5
# Restoring model weights from the end of the best epoch: 30.
# [full | epochs=30 | seed=4] acc=0.8706 macro_f1=0.8574
#
# Epoch 1: val_loss improved from None to 0.51364, saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 2: val_loss improved from 0.51364 to 0.47508, saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 3: val_loss did not improve from 0.47508
#
# Epoch 4: val_loss did not improve from 0.47508
#
# Epoch 5: val_loss improved from 0.47508 to 0.45530, saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 5: finished saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 6: val_loss did not improve from 0.45530
#
# Epoch 7: val_loss improved from 0.45530 to 0.44949, saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 7: finished saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 8: val_loss did not improve from 0.44949
#
# Epoch 9: val_loss did not improve from 0.44949
#
# Epoch 10: val_loss improved from 0.44949 to 0.42615, saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 10: finished saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 11: val_loss did not improve from 0.42615
#
# Epoch 12: val_loss did not improve from 0.42615
#
# Epoch 13: val_loss improved from 0.42615 to 0.42531, saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 13: finished saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 14: val_loss improved from 0.42531 to 0.41075, saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/no_topic_ep15_seed0.weights.h5
#
# Epoch 15: val_loss did not improve from 0.41075
# Restoring model weights from the end of the best epoch: 14.
# [no_topic | epochs=15 | seed=0] acc=0.8366 macro_f1=0.8203
#
# Epoch 1: val_loss improved from None to 0.49406, saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 2: val_loss did not improve from 0.49406
#
# Epoch 3: val_loss improved from 0.49406 to 0.47143, saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 3: finished saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 4: val_loss did not improve from 0.47143
#
# Epoch 5: val_loss improved from 0.47143 to 0.46797, saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 5: finished saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 6: val_loss improved from 0.46797 to 0.44878, saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 7: val_loss improved from 0.44878 to 0.44200, saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 7: finished saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 8: val_loss did not improve from 0.44200
#
# Epoch 9: val_loss improved from 0.44200 to 0.43958, saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 9: finished saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 10: val_loss improved from 0.43958 to 0.43078, saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 10: finished saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 11: val_loss did not improve from 0.43078
#
# Epoch 12: val_loss did not improve from 0.43078
#
# Epoch 13: val_loss improved from 0.43078 to 0.42582, saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 13: finished saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 14: val_loss improved from 0.42582 to 0.42071, saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 15: val_loss improved from 0.42071 to 0.42053, saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
#
# Epoch 15: finished saving model to ./ablation_ckpt/no_topic_ep15_seed1.weights.h5
# Restoring model weights from the end of the best epoch: 15.
# [no_topic | epochs=15 | seed=1] acc=0.8350 macro_f1=0.8208
#
# Epoch 1: val_loss improved from None to 0.51886, saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 2: val_loss improved from 0.51886 to 0.49355, saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 3: val_loss did not improve from 0.49355
#
# Epoch 4: val_loss improved from 0.49355 to 0.47930, saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 4: finished saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 5: val_loss improved from 0.47930 to 0.45829, saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 5: finished saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 6: val_loss did not improve from 0.45829
#
# Epoch 7: val_loss improved from 0.45829 to 0.44034, saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 7: finished saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 8: val_loss did not improve from 0.44034
#
# Epoch 9: val_loss did not improve from 0.44034
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 10: val_loss did not improve from 0.44034
#
# Epoch 11: val_loss improved from 0.44034 to 0.40880, saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 11: finished saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 12: val_loss did not improve from 0.40880
#
# Epoch 13: val_loss improved from 0.40880 to 0.40180, saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 13: finished saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 14: val_loss did not improve from 0.40180
#
# Epoch 15: val_loss improved from 0.40180 to 0.39684, saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
#
# Epoch 15: finished saving model to ./ablation_ckpt/no_topic_ep15_seed2.weights.h5
# Restoring model weights from the end of the best epoch: 15.
# [no_topic | epochs=15 | seed=2] acc=0.8440 macro_f1=0.8292
#
# Epoch 1: val_loss improved from None to 0.50131, saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 2: val_loss did not improve from 0.50131
#
# Epoch 3: val_loss improved from 0.50131 to 0.48563, saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 3: finished saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 4: val_loss did not improve from 0.48563
#
# Epoch 5: val_loss improved from 0.48563 to 0.47035, saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 5: finished saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 6: val_loss improved from 0.47035 to 0.44600, saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 7: val_loss did not improve from 0.44600
#
# Epoch 8: val_loss did not improve from 0.44600
#
# Epoch 9: val_loss improved from 0.44600 to 0.43847, saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 9: finished saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 10: val_loss improved from 0.43847 to 0.43387, saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 10: finished saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 11: val_loss improved from 0.43387 to 0.42086, saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 11: finished saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 12: val_loss did not improve from 0.42086
#
# Epoch 13: val_loss did not improve from 0.42086
#
# Epoch 14: val_loss improved from 0.42086 to 0.40716, saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/no_topic_ep15_seed3.weights.h5
#
# Epoch 15: val_loss did not improve from 0.40716
# Restoring model weights from the end of the best epoch: 14.
# [no_topic | epochs=15 | seed=3] acc=0.8390 macro_f1=0.8228
#
# Epoch 1: val_loss improved from None to 0.52662, saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 2: val_loss improved from 0.52662 to 0.49714, saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 3: val_loss improved from 0.49714 to 0.47606, saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 3: finished saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 4: val_loss improved from 0.47606 to 0.46205, saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 4: finished saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 5: val_loss improved from 0.46205 to 0.45820, saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 5: finished saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 6: val_loss improved from 0.45820 to 0.45081, saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 7: val_loss did not improve from 0.45081
#
# Epoch 8: val_loss improved from 0.45081 to 0.44311, saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 8: finished saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 9: val_loss did not improve from 0.44311
#
# Epoch 10: val_loss improved from 0.44311 to 0.42734, saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 10: finished saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 11: val_loss improved from 0.42734 to 0.41971, saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 11: finished saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 12: val_loss did not improve from 0.41971
#
# Epoch 13: val_loss did not improve from 0.41971
#
# Epoch 14: val_loss improved from 0.41971 to 0.41146, saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 15: val_loss improved from 0.41146 to 0.40774, saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
#
# Epoch 15: finished saving model to ./ablation_ckpt/no_topic_ep15_seed4.weights.h5
# Restoring model weights from the end of the best epoch: 15.
# [no_topic | epochs=15 | seed=4] acc=0.8431 macro_f1=0.8276
#
# Epoch 1: val_loss improved from None to 0.49732, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 2: val_loss did not improve from 0.49732
#
# Epoch 3: val_loss improved from 0.49732 to 0.46519, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 3: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 4: val_loss did not improve from 0.46519
#
# Epoch 5: val_loss improved from 0.46519 to 0.46322, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 5: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 6: val_loss improved from 0.46322 to 0.44670, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 7: val_loss did not improve from 0.44670
#
# Epoch 8: val_loss improved from 0.44670 to 0.43365, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 8: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 9: val_loss did not improve from 0.43365
#
# Epoch 10: val_loss improved from 0.43365 to 0.42373, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 10: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 11: val_loss did not improve from 0.42373
#
# Epoch 12: val_loss improved from 0.42373 to 0.41642, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 12: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 13: val_loss did not improve from 0.41642
#
# Epoch 14: val_loss improved from 0.41642 to 0.41414, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 15: val_loss did not improve from 0.41414
#
# Epoch 16: val_loss did not improve from 0.41414
#
# Epoch 17: val_loss improved from 0.41414 to 0.39626, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 17: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 18: val_loss did not improve from 0.39626
#
# Epoch 19: val_loss improved from 0.39626 to 0.39476, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 19: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 20: val_loss did not improve from 0.39476
#
# Epoch 21: val_loss did not improve from 0.39476
#
# Epoch 22: val_loss improved from 0.39476 to 0.38838, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 22: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 23: val_loss improved from 0.38838 to 0.38153, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 23: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 24: val_loss did not improve from 0.38153
#
# Epoch 25: val_loss improved from 0.38153 to 0.38086, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 25: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 26: val_loss improved from 0.38086 to 0.36257, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 26: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 27: val_loss improved from 0.36257 to 0.36214, saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 27: finished saving model to ./ablation_ckpt/no_topic_ep30_seed0.weights.h5
#
# Epoch 28: val_loss did not improve from 0.36214
#
# Epoch 29: val_loss did not improve from 0.36214
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 30: val_loss did not improve from 0.36214
# ...
#
# Epoch 4: val_loss improved from 0.47274 to 0.46754, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 4: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 5: val_loss did not improve from 0.46754
#
# Epoch 6: val_loss improved from 0.46754 to 0.45392, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 7: val_loss did not improve from 0.45392
#
# Epoch 8: val_loss did not improve from 0.45392
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 9: val_loss did not improve from 0.45392
#
# Epoch 10: val_loss improved from 0.45392 to 0.43200, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 10: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 11: val_loss did not improve from 0.43200
#
# Epoch 12: val_loss improved from 0.43200 to 0.42723, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 12: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 13: val_loss did not improve from 0.42723
#
# Epoch 14: val_loss improved from 0.42723 to 0.42144, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 15: val_loss improved from 0.42144 to 0.41408, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 15: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 16: val_loss improved from 0.41408 to 0.41244, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 16: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 17: val_loss did not improve from 0.41244
#
# Epoch 18: val_loss improved from 0.41244 to 0.40739, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 18: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 19: val_loss improved from 0.40739 to 0.40457, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 19: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 20: val_loss did not improve from 0.40457
#
# Epoch 21: val_loss improved from 0.40457 to 0.40171, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 21: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 22: val_loss improved from 0.40171 to 0.39880, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 22: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 23: val_loss did not improve from 0.39880
#
# Epoch 24: val_loss improved from 0.39880 to 0.38834, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 24: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 25: val_loss did not improve from 0.38834
#
# Epoch 26: val_loss did not improve from 0.38834
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 27: val_loss did not improve from 0.38834
#
# Epoch 28: val_loss did not improve from 0.38834
#
# Epoch 29: val_loss improved from 0.38834 to 0.38150, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 29: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 30: val_loss improved from 0.38150 to 0.37980, saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
#
# Epoch 30: finished saving model to ./ablation_ckpt/no_bn_ep30_seed1.weights.h5
# Restoring model weights from the end of the best epoch: 30.
# [no_bn | epochs=30 | seed=1] acc=0.8527 macro_f1=0.8385
#
# Epoch 1: val_loss improved from None to 0.48976, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 2: val_loss improved from 0.48976 to 0.46286, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 3: val_loss did not improve from 0.46286
#
# Epoch 4: val_loss improved from 0.46286 to 0.46106, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 4: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 5: val_loss improved from 0.46106 to 0.45404, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 5: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 6: val_loss did not improve from 0.45404
#
# Epoch 7: val_loss did not improve from 0.45404
#
# Epoch 8: val_loss improved from 0.45404 to 0.44942, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 8: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 9: val_loss improved from 0.44942 to 0.44522, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 9: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 10: val_loss improved from 0.44522 to 0.43784, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 10: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 11: val_loss did not improve from 0.43784
#
# Epoch 12: val_loss did not improve from 0.43784
#
# Epoch 13: val_loss improved from 0.43784 to 0.43173, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 13: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 14: val_loss improved from 0.43173 to 0.43154, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 15: val_loss did not improve from 0.43154
#
# Epoch 16: val_loss improved from 0.43154 to 0.42624, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 16: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 17: val_loss did not improve from 0.42624
#
# Epoch 18: val_loss did not improve from 0.42624
#
# Epoch 19: val_loss improved from 0.42624 to 0.41946, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 19: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 20: val_loss improved from 0.41946 to 0.40755, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 20: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 21: val_loss did not improve from 0.40755
#
# Epoch 22: val_loss improved from 0.40755 to 0.40088, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 22: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 23: val_loss did not improve from 0.40088
#
# Epoch 24: val_loss did not improve from 0.40088
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 25: val_loss did not improve from 0.40088
#
# Epoch 26: val_loss improved from 0.40088 to 0.39971, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 26: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 27: val_loss improved from 0.39971 to 0.39572, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 27: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 28: val_loss improved from 0.39572 to 0.38932, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 28: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 29: val_loss improved from 0.38932 to 0.38508, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 29: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 30: val_loss improved from 0.38508 to 0.38179, saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
#
# Epoch 30: finished saving model to ./ablation_ckpt/no_bn_ep30_seed2.weights.h5
# Restoring model weights from the end of the best epoch: 30.
# [no_bn | epochs=30 | seed=2] acc=0.8512 macro_f1=0.8371
#
# Epoch 1: val_loss improved from None to 0.52475, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 2: val_loss improved from 0.52475 to 0.49957, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 3: val_loss improved from 0.49957 to 0.47296, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 3: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 4: val_loss improved from 0.47296 to 0.46491, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 4: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 5: val_loss improved from 0.46491 to 0.46045, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 5: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 6: val_loss did not improve from 0.46045
#
# Epoch 7: val_loss improved from 0.46045 to 0.44907, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 7: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 8: val_loss improved from 0.44907 to 0.44662, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 8: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 9: val_loss did not improve from 0.44662
#
# Epoch 10: val_loss did not improve from 0.44662
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_loss did not improve from 0.44662
#
# Epoch 12: val_loss improved from 0.44662 to 0.42733, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 12: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 13: val_loss did not improve from 0.42733
#
# Epoch 14: val_loss improved from 0.42733 to 0.42601, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 15: val_loss improved from 0.42601 to 0.41632, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 15: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 16: val_loss improved from 0.41632 to 0.41479, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 16: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 17: val_loss did not improve from 0.41479
#
# Epoch 18: val_loss improved from 0.41479 to 0.41047, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 18: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 19: val_loss did not improve from 0.41047
#
# Epoch 20: val_loss did not improve from 0.41047
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 21: val_loss did not improve from 0.41047
#
# Epoch 22: val_loss improved from 0.41047 to 0.40597, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 22: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 23: val_loss did not improve from 0.40597
#
# Epoch 24: val_loss improved from 0.40597 to 0.39588, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 24: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 25: val_loss did not improve from 0.39588
#
# Epoch 26: val_loss did not improve from 0.39588
#
# Epoch 27: val_loss improved from 0.39588 to 0.39125, saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 27: finished saving model to ./ablation_ckpt/no_bn_ep30_seed3.weights.h5
#
# Epoch 28: val_loss did not improve from 0.39125
#
# Epoch 29: val_loss did not improve from 0.39125
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 30: val_loss did not improve from 0.39125
# Restoring model weights from the end of the best epoch: 27.
# [no_bn | epochs=30 | seed=3] acc=0.8452 macro_f1=0.8310
#
# Epoch 1: val_loss improved from None to 0.48757, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 1: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 2: val_loss improved from 0.48757 to 0.47007, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 2: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 3: val_loss improved from 0.47007 to 0.46863, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 3: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 4: val_loss did not improve from 0.46863
#
# Epoch 5: val_loss did not improve from 0.46863
#
# Epoch 6: val_loss improved from 0.46863 to 0.45035, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 6: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 7: val_loss improved from 0.45035 to 0.44786, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 7: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 8: val_loss improved from 0.44786 to 0.44052, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 8: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 9: val_loss did not improve from 0.44052
#
# Epoch 10: val_loss did not improve from 0.44052
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_loss did not improve from 0.44052
#
# Epoch 12: val_loss improved from 0.44052 to 0.43748, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 12: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 13: val_loss improved from 0.43748 to 0.42049, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 13: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 14: val_loss improved from 0.42049 to 0.41711, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 14: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 15: val_loss did not improve from 0.41711
#
# Epoch 16: val_loss did not improve from 0.41711
#
# Epoch 17: val_loss improved from 0.41711 to 0.41110, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 17: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 18: val_loss did not improve from 0.41110
#
# Epoch 19: val_loss improved from 0.41110 to 0.40489, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 19: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 20: val_loss did not improve from 0.40489
#
# Epoch 21: val_loss did not improve from 0.40489
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 22: val_loss did not improve from 0.40489
#
# Epoch 23: val_loss improved from 0.40489 to 0.39842, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 23: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 24: val_loss improved from 0.39842 to 0.39388, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 24: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 25: val_loss did not improve from 0.39388
#
# Epoch 26: val_loss did not improve from 0.39388
#
# Epoch 27: val_loss improved from 0.39388 to 0.38968, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 27: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 28: val_loss improved from 0.38968 to 0.38743, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 28: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 29: val_loss did not improve from 0.38743
#
# Epoch 30: val_loss improved from 0.38743 to 0.38658, saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
#
# Epoch 30: finished saving model to ./ablation_ckpt/no_bn_ep30_seed4.weights.h5
# Restoring model weights from the end of the best epoch: 30.
# [no_bn | epochs=30 | seed=4] acc=0.8515 macro_f1=0.8380
#
# Saved 40 raw ablation runs -> ./artifacts/ablation_raw_results.csv

# %%
# --- Ablation Results — Mean ± Std by Variant ---
ablation_summary = ablation_df.groupby(['variant', 'epochs']).agg(
    accuracy_mean=('accuracy', 'mean'), accuracy_std=('accuracy', 'std'),
    macro_f1_mean=('macro_f1', 'mean'), macro_f1_std=('macro_f1', 'std'),
).reset_index()

print("=" * 90)
print(f"ABLATION SUMMARY (mean ± std over {N_SEEDS} seeds)")
print("=" * 90)
for _, row in ablation_summary.iterrows():
    print(f"  {row['variant']:>10s} | epochs={int(row['epochs']):>2d} | "
          f"acc = {row['accuracy_mean']:.4f} ± {row['accuracy_std']:.4f} | "
          f"macro_f1 = {row['macro_f1_mean']:.4f} ± {row['macro_f1_std']:.4f}")

ablation_summary.to_csv('./artifacts/ablation_summary_table.csv', index=False)

# Rank components by how much macro_f1 drops relative to 'full' at the same epoch budget
print("\nComponent impact (drop in mean macro_f1 vs. 'full', at epochs=30):")
full_f1 = ablation_summary.query("variant == 'full' and epochs == 30")['macro_f1_mean'].iloc[0]
impact = (
    ablation_summary.query("epochs == 30 and variant != 'full'")
    .assign(drop_vs_full=lambda d: full_f1 - d['macro_f1_mean'])
    .sort_values('drop_vs_full', ascending=False)
)
print(impact[['variant', 'macro_f1_mean', 'drop_vs_full']].to_string(index=False))
print("\nSaved: ./artifacts/ablation_summary_table.csv")
# Out:
# ==========================================================================================
# ABLATION SUMMARY (mean ± std over 5 seeds)
# ==========================================================================================
#         full | epochs=15 | acc = 0.8462 ± 0.0039 | macro_f1 = 0.8313 ± 0.0043
#         full | epochs=30 | acc = 0.8737 ± 0.0023 | macro_f1 = 0.8612 ± 0.0028
#        no_bn | epochs=15 | acc = 0.8311 ± 0.0041 | macro_f1 = 0.8154 ± 0.0045
#        no_bn | epochs=30 | acc = 0.8496 ± 0.0032 | macro_f1 = 0.8356 ± 0.0033
#      no_skip | epochs=15 | acc = 0.8426 ± 0.0038 | macro_f1 = 0.8276 ± 0.0044
#      no_skip | epochs=30 | acc = 0.8707 ± 0.0033 | macro_f1 = 0.8574 ± 0.0034
#     no_topic | epochs=15 | acc = 0.8395 ± 0.0039 | macro_f1 = 0.8241 ± 0.0040
#     no_topic | epochs=30 | acc = 0.8623 ± 0.0042 | macro_f1 = 0.8491 ± 0.0047
#
# Component impact (drop in mean macro_f1 vs. 'full', at epochs=30):
#  variant  macro_f1_mean  drop_vs_full
#    no_bn       0.835562      0.025626
# no_topic       0.849068      0.012121
#  no_skip       0.857356      0.003832
#
# Saved: ./artifacts/ablation_summary_table.csv

# %% [markdown]
# Ablation by domain (Table 4 split, epochs=30, 5 seeds — reuses existing checkpoints)

# %%
domain_ablation_rows = []
for variant in ABLATION_VARIANTS:
    for seed in range(N_SEEDS):
        ckpt = f'{ablation_ckpt_dir}/{variant}_ep30_seed{seed}.weights.h5'
        m = build_model_ablation(variant, ROBERTA_DIM, NUM_TOPICS, NUM_CLASSES, TOPIC_EMB_DIM, DROPOUT_RATE)
        m.load_weights(ckpt)
        y_hat = np.argmax(m.predict(test_ds, verbose=0), axis=1)
        for d in ['social-media', 'hotel-review']:
            mask = domain == d
            domain_ablation_rows.append({
                'variant': variant, 'seed': seed, 'domain': d,
                'accuracy': accuracy_score(y_test[mask], y_hat[mask]),
                'macro_f1': f1_score(y_test[mask], y_hat[mask], average='macro')})
        del m; tf.keras.backend.clear_session()

dab_df = pd.DataFrame(domain_ablation_rows)
dab_summary = dab_df.groupby(['variant','domain']).agg(
    accuracy_mean=('accuracy','mean'), accuracy_std=('accuracy','std'),
    macro_f1_mean=('macro_f1','mean'), macro_f1_std=('macro_f1','std')).reset_index()
print(dab_summary.to_string(index=False))
dab_df.to_csv('./artifacts/ablation_raw_results_by_domain.csv', index=False)
dab_summary.to_csv('./artifacts/table4_by_domain.csv', index=False)

# Trả lời trực tiếp 2 câu hỏi reviewer:
piv = dab_summary.pivot(index='domain', columns='variant', values='macro_f1_mean')
print("\nQ: Does topic help equally across domains? (full - no_topic, macro-F1)")
print((piv['full'] - piv['no_topic']))
print("\nQ: Does the frozen encoder transfer equally? -> so sánh full-model acc/macro-F1 giữa 2 domain ở bảng table2_by_domain.csv phía trên.")
# Out:
#  variant       domain  accuracy_mean  accuracy_std  macro_f1_mean  macro_f1_std
#     full hotel-review       0.926611      0.002417       0.741642      0.008357
#     full social-media       0.815336      0.006010       0.810381      0.006448
#    no_bn hotel-review       0.928616      0.001723       0.733803      0.008468
#    no_bn social-media       0.762512      0.006655       0.754192      0.007350
#  no_skip hotel-review       0.924205      0.001045       0.742865      0.011223
#  no_skip social-media       0.811739      0.006603       0.808187      0.006667
# no_topic hotel-review       0.924950      0.002144       0.746851      0.005508
# no_topic social-media       0.793310      0.009000       0.786373      0.009938
#
# Q: Does topic help equally across domains? (full - no_topic, macro-F1)
# domain
# hotel-review   -0.005209
# social-media    0.024008
# dtype: float64
#
# Q: Does the frozen encoder transfer equally? -> so sánh full-model acc/macro-F1 giữa 2 domain ở bảng table2_by_domain.csv phía trên.

# %%
from scipy import stats
raw = pd.read_csv('./artifacts/ablation_raw_results.csv')
full = raw[(raw.variant=='full') & (raw.epochs==30)].sort_values('seed')

sig_rows = []
for variant in ['no_topic', 'no_skip', 'no_bn']:
    var = raw[(raw.variant==variant) & (raw.epochs==30)].sort_values('seed')
    assert (full.seed.values == var.seed.values).all()
    for metric in ['accuracy', 'macro_f1']:
        a, b = full[metric].values, var[metric].values
        t_stat, t_p = stats.ttest_rel(a, b)
        try: w_stat, w_p = stats.wilcoxon(a, b)
        except ValueError: w_stat, w_p = np.nan, np.nan
        sig_rows.append({'variant': variant, 'metric': metric, 'diff': a.mean()-b.mean(),
                          't_pvalue': t_p, 'wilcoxon_pvalue': w_p})
sig_df = pd.DataFrame(sig_rows)
print(sig_df.to_string(index=False))
sig_df.to_csv('./artifacts/table4_significance.csv', index=False)
# Out:
#  variant   metric     diff  t_pvalue  wilcoxon_pvalue
# no_topic accuracy 0.011351  0.009123           0.0625
# no_topic macro_f1 0.012121  0.012196           0.0625
#  no_skip accuracy 0.002973  0.217990           0.3125
#  no_skip macro_f1 0.003832  0.152687           0.1875
#    no_bn accuracy 0.024084  0.000112           0.0625
#    no_bn macro_f1 0.025626  0.000160           0.0625

# %% [markdown]
# ---
# ## 🔮 Step 7: Inference Demo
#
# Reload the RoBERTa model and test with sample COVID-19 related tweets.

# %%
# Reload RoBERTa for inference (lightweight — only needed for single predictions)
roberta_inference = AutoModel.from_pretrained(MODEL_NAME)
roberta_inference.to(DEVICE)
roberta_inference.eval()

def predict_sentiment(text, topic_str=None):
    """
    Predict sentiment for a single tweet.

    Args:
        text (str): Tweet content
        topic_str (str, optional): Topic name. If None (default), the topic is auto-predicted
            from the tweet's own cleaned text via the Step 3.4 TF-IDF topic classifier — no manual
            topic label is required. Pass an explicit topic to override the auto-prediction.

    Returns:
        dict: {'sentiment': str, 'confidence': float, 'probabilities': dict,
               'topic': str, 'topic_source': 'auto' | 'manual'}
    """
    # Clean the input text
    cleaned = clean_text(text)

    # Tokenize & extract embedding with PyTorch — done once, shared by topic auto-prediction and
    # the sentiment head below (no need for two separate RoBERTa forward passes).
    encoding = tokenizer(
        cleaned,
        max_length=MAX_LEN,
        padding='max_length',
        truncation=True,
        return_tensors='pt'
    )
    input_ids = encoding['input_ids'].to(DEVICE)
    attention_mask = encoding['attention_mask'].to(DEVICE)

    with torch.no_grad():
        outputs = roberta_inference(input_ids=input_ids, attention_mask=attention_mask)
    # Use same mean pooling as training
    embedding = mean_pooling(outputs.last_hidden_state, attention_mask).cpu().numpy()  # (1, 768)

    if topic_str is None:
        topic_str = predict_topic_from_text(cleaned)
        topic_source = 'auto'
    else:
        topic_source = 'manual'

    # Encode topic
    try:
        topic_id = topic_encoder.transform([topic_str])[0]
    except ValueError:
        print(f"  Unknown topic '{topic_str}'. Using index 0 as fallback.")
        topic_id = 0

    # Predict with Keras model
    inputs = {
        'text_embedding': embedding.astype(np.float32),
        'topic_id': np.array([[topic_id]], dtype=np.int32)
    }

    probs = model.predict(inputs, verbose=0)[0]
    pred_idx = np.argmax(probs)
    pred_label = sentiment_encoder.inverse_transform([pred_idx])[0]

    # Build probabilities dict
    prob_dict = {
        sentiment_encoder.classes_[i]: float(probs[i])
        for i in range(len(sentiment_encoder.classes_))
    }

    return {
        'sentiment': pred_label,
        'confidence': float(probs[pred_idx]),
        'probabilities': prob_dict,
        'topic': topic_str,
        'topic_source': topic_source,
    }
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] RobertaModel LOAD REPORT from: cardiffnlp/twitter-roberta-base-sentiment-latest
# Key                        | Status     |  |
# ---------------------------+------------+--+-
# classifier.out_proj.weight | UNEXPECTED |  |
# classifier.out_proj.bias   | UNEXPECTED |  |
# classifier.dense.weight    | UNEXPECTED |  |
# classifier.dense.bias      | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# ### 🧪 Test Examples

# %%
test_examples = [
    "Another patch, another broken champion ruining ranked. The balance team actually has no idea what they are doing. Vanguard keeps crashing my PC and cost me 50 LP today. Im so done with this game 🤬 #LeagueOfLegends",
]

print("=" * 70)
print("Test examples (topic is auto-predicted — Step 6.7 — not supplied manually)")
print("=" * 70)

for i, text in enumerate(test_examples, 1):
    result = predict_sentiment(text)  # topic_str=None -> auto-predicted, then fed into the sentiment head
    print(f"\n--- Example {i} ---")
    print(f"  Text:            {text}")
    print(f"  Predicted topic: {result['topic']} (source: {result['topic_source']})")
    print(f"  Prediction:      {result['sentiment']} (confidence: {result['confidence']:.4f})")
    print(f"  Probs:           {', '.join(f'{k}: {v:.4f}' for k, v in result['probabilities'].items())}")

print("\n Pipeline complete!")
# Out:
# ======================================================================
# Test examples (topic is auto-predicted — Step 6.7 — not supplied manually)
# ======================================================================
#
# --- Example 1 ---
#   Text:            Another patch, another broken champion ruining ranked. The balance team actually has no idea what they are doing. Vanguard keeps crashing my PC and cost me 50 LP today. Im so done with this game 🤬 #LeagueOfLegends
#   Predicted topic: League Of Legends (source: auto)
#   Prediction:      Negative (confidence: 0.8247)
#   Probs:           Negative: 0.8247, Neutral: 0.1307, Positive: 0.0446
#
#  Pipeline complete!

# %% [markdown]
# ---
# ## 🔍 Step 8: LIME-based Token Attribution

# %%
# !pip install lime
# --- 8.1 LIME-compatible prediction wrapper ---
from lime.lime_text import LimeTextExplainer

def make_lime_predict_fn(topic_str):
    """
    Factory: returns a LIME-compatible predict function for a given topic.

    The returned function: list[str] → np.ndarray of shape (N, 3) probabilities.
    It re-embeds each perturbed text through the full pipeline.
    """
    # Encode topic once
    try:
        tid = topic_encoder.transform([topic_str])[0]
    except ValueError:
        tid = 0

    def predict_fn(texts):
        # Clean all texts
        cleaned = [clean_text(t) for t in texts]
        # Handle empty strings after cleaning
        cleaned = [t if len(t) > 0 else "empty" for t in cleaned]

        # Tokenize batch with RoBERTa
        encoding = tokenizer(
            cleaned,
            max_length=MAX_LEN,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )
        input_ids = encoding['input_ids'].to(DEVICE)
        attention_mask = encoding['attention_mask'].to(DEVICE)

        # Extract mean-pooled embeddings
        with torch.no_grad():
            outputs = roberta_inference(input_ids=input_ids, attention_mask=attention_mask)
        embeddings = mean_pooling(outputs.last_hidden_state, attention_mask).cpu().numpy()

        # Predict with Keras model
        batch_size = len(texts)
        inputs = {
            'text_embedding': embeddings.astype(np.float32),
            'topic_id': np.full((batch_size, 1), tid, dtype=np.int32)
        }
        probs = model.predict(inputs, verbose=0)
        return probs

    return predict_fn

# Initialize LIME explainer
lime_explainer = LimeTextExplainer(
    class_names=sentiment_encoder.classes_.tolist(),
    split_expression=r'\W+',
    random_state=SEED
)

print("✅ LIME explainer and wrapper ready.")
# Out:
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from lime) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from lime) (2.1.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from lime) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from lime) (4.67.3)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.13/dist-packages (from lime) (1.6.1)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.13/dist-packages (from lime) (0.25.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.13/dist-packages (from scikit-image>=0.12->lime) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.13/dist-packages (from scikit-image>=0.12->lime) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.13/dist-packages (from scikit-image>=0.12->lime) (2.37.4)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.13/dist-packages (from scikit-image>=0.12->lime) (2026.8.23)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.13/dist-packages (from scikit-image>=0.12->lime) (26.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.13/dist-packages (from scikit-image>=0.12->lime) (0.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=0.18->lime) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=0.18->lime) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->lime) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->lime) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->lime) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->lime) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->lime) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=4dfdc06bb2a4c96030a1a46db751598349f6bdae142953257e1ee47a8f3d71c4
#   Stored in directory: /root/.cache/pip/wheels/7c/04/5c/157dc9106512a6c7a30653ec064490c94a49e0fc8f63d19ab9
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1
# ✅ LIME explainer and wrapper ready.

# %% [markdown]
# ### 8.2 LIME Demo — Explain Individual Predictions

# %%
# --- 8.2 Run LIME on demo tweets ---
lime_demo_tweets = [
    "Another patch, another broken champion ruining ranked. The balance team actually has no idea what they are doing. Vanguard keeps crashing my PC and cost me 50 LP today. Im so done with this game 🤬 #LeagueOfLegends",
]

lime_results = []  # Store for Steps 9-11

for i, tweet in enumerate(lime_demo_tweets, 1):
    # LIME must explain the SAME string the model actually sees. predict_fn (cell 8.1) calls
    # clean_text() on every perturbed sample before scoring it, so if we hand explain_instance the
    # raw tweet, LIME's displayed tokens (capitalized words, digits, '#hashtags') would not match
    # what the model receives -> misleading attributions. Explain the cleaned text directly instead.
    cleaned_tweet = clean_text(tweet)

    # Topic is auto-predicted (Step 3.4, TF-IDF), not supplied manually — predict_sentiment() does
    # this internally and returns the topic it used, so we can reuse the exact same value below.
    baseline = predict_sentiment(tweet)
    pred_label = baseline['sentiment']
    pred_conf = baseline['confidence']
    topic = baseline['topic']
    # LimeTextExplainer.explain_instance()/as_list()/as_pyplot_figure() all default to label=1
    # ("Neutral", since sentiment_encoder.classes_ is alphabetical: Negative=0, Neutral=1,
    # Positive=2) unless told otherwise. Without this, LIME would silently explain "Neutral" even
    # when the model actually predicted "Negative"/"Positive" — pin it to the class we're reporting.
    pred_idx = int(sentiment_encoder.transform([pred_label])[0])

    print(f"\n{'='*70}")
    print(f"LIME Example {i}")
    print(f"{'='*70}")
    print(f"  Raw tweet:                                  {tweet}")
    print(f"  Cleaned tweet (LIME explains THIS string):  {cleaned_tweet}")
    print(f"  Predicted topic: {topic} (source: {baseline['topic_source']})")
    print(f"  Prediction:      {pred_label} (confidence: {pred_conf:.4f})")
    print(f"  Probabilities: {', '.join(f'{k}: {v:.4f}' for k,v in baseline['probabilities'].items())}")

    # Run LIME. The topic is fixed to the auto-predicted value above so word-level attributions
    # aren't confounded by the topic also drifting across LIME's perturbed samples. `labels`
    # pins the explanation to the class actually predicted (see pred_idx note above).
    predict_fn = make_lime_predict_fn(topic)
    explanation = lime_explainer.explain_instance(
        cleaned_tweet, predict_fn,
        labels=(pred_idx,),
        num_features=10,
        num_samples=500
    )

    # Extract top words for the predicted class specifically (NOT the label=1 default).
    word_weights = explanation.as_list(label=pred_idx)
    positive_words = [(w, wt) for w, wt in word_weights if wt > 0]
    negative_words = [(w, wt) for w, wt in word_weights if wt < 0]

    print(f"\n  Top POSITIVE influence words (push toward '{pred_label}'):")
    for w, wt in positive_words[:5]:
        print(f"    '{w}': {wt:+.4f}")

    print(f"\n  Top NEGATIVE influence words (push away from '{pred_label}'):")
    for w, wt in negative_words[:5]:
        print(f"    '{w}': {wt:+.4f}")

    # Store result for later steps
    lime_results.append({
        'tweet': tweet,
        'cleaned_tweet': cleaned_tweet,
        'topic': topic,
        'prediction': baseline,
        'positive_words': positive_words,
        'negative_words': negative_words,
        'explanation': explanation,
    })

    # Visualize (also pinned to pred_idx, otherwise this plot shows the "Neutral" explanation
    # under a title that claims to be for pred_label).
    fig = explanation.as_pyplot_figure(label=pred_idx)
    fig.set_size_inches(10, 5)
    plt.title(f"LIME: Example {i} — Predicted {pred_label} ({pred_conf:.2%})", fontweight='bold')
    plt.tight_layout()
    os.makedirs('lime_figure', exist_ok=True)
    plt.savefig(f'lime_figure/lime_step8_example_{i}.png', dpi=150, bbox_inches='tight')
    plt.show()

print(f"\n✅ LIME analysis complete for {len(lime_demo_tweets)} tweets.")

# --- 8.3 LIME Demo — hotel-review domain (R1-iii) ---
lime_demo_tweets_hotel = [
    "Well, I really regretted is as I woke up to disco music on a Tuesday night and couldn't sleep for 3 hours because of the loud noises.",
    "Very comfortable, very helpful staff, delicious breakfast, very convenient to metro or ferry into the centre.",
]
lime_results_hotel = []
for i, tweet in enumerate(lime_demo_tweets_hotel, 1):
    cleaned_tweet = clean_text(tweet)
    baseline = predict_sentiment(tweet)
    pred_label, pred_conf, topic = baseline['sentiment'], baseline['confidence'], baseline['topic']
    pred_idx = int(sentiment_encoder.transform([pred_label])[0])
    print(f"\n{'='*70}\nLIME Example (hotel) {i}\n{'='*70}")
    print(f"  Raw: {tweet}\n  Predicted topic: {topic} ({baseline['topic_source']})")
    print(f"  Prediction: {pred_label} (conf {pred_conf:.4f})")

    predict_fn = make_lime_predict_fn(topic)
    explanation = lime_explainer.explain_instance(cleaned_tweet, predict_fn, labels=(pred_idx,),
                                                    num_features=10, num_samples=500)
    word_weights = explanation.as_list(label=pred_idx)
    pos_w = [(w,wt) for w,wt in word_weights if wt>0]
    neg_w = [(w,wt) for w,wt in word_weights if wt<0]
    print("  TOWARD:", pos_w[:5]); print("  AWAY:", neg_w[:5])
    lime_results_hotel.append({'tweet': tweet, 'topic': topic, 'prediction': baseline,
                                'positive_words': pos_w, 'negative_words': neg_w})
    fig = explanation.as_pyplot_figure(label=pred_idx)
    fig.set_size_inches(10, 5)
    plt.title(f"LIME: Hotel Example {i} — {pred_label} ({pred_conf:.2%})", fontweight='bold')
    plt.tight_layout()
    plt.savefig(f'lime_figure/lime_step8_hotel_example_{i}.png', dpi=150, bbox_inches='tight')
    plt.show()
# Out:
# ======================================================================
# LIME Example 1
# ======================================================================
#   Raw tweet:                                  Another patch, another broken champion ruining ranked. The balance team actually has no idea what they are doing. Vanguard keeps crashing my PC and cost me 50 LP today. Im so done with this game 🤬 #LeagueOfLegends
#   Cleaned tweet (LIME explains THIS string):  another patch another broken champion ruining ranked the balance team actually has no idea what they are doing vanguard keeps crashing my pc and cost me lp today i am so done with this game
#   Predicted topic: League Of Legends (source: auto)
#   Prediction:      Negative (confidence: 0.8247)
#   Probabilities: Negative: 0.8247, Neutral: 0.1307, Positive: 0.0446
#
#   Top POSITIVE influence words (push toward 'Negative'):
#     'another': +0.0918
#     'ruining': +0.0815
#     'done': +0.0737
#     'crashing': +0.0660
#     'my': +0.0545
#
#   Top NEGATIVE influence words (push away from 'Negative'):
#     'champion': -0.0398
#     'pc': -0.0350
#     'are': -0.0208
#     'lp': -0.0168
# ✅ LIME analysis complete for 1 tweets.
#
# ======================================================================
# LIME Example (hotel) 1
# ======================================================================
#   Raw: Well, I really regretted is as I woke up to disco music on a Tuesday night and couldn't sleep for 3 hours because of the loud noises.
#   Predicted topic: hotel (auto)
#   Prediction: Negative (conf 0.9995)
#   TOWARD: [(np.str_('regretted'), 0.037915822998806616), (np.str_('noises'), 0.035336425861687205), (np.str_('not'), 0.028494746526734508), (np.str_('loud'), 0.024910099761036714), (np.str_('on'), 0.020436641779489905)]
#   AWAY: [(np.str_('and'), -0.010464454362598248), (np.str_('tuesday'), -0.009359871930944324)]
# ======================================================================
# LIME Example (hotel) 2
# ======================================================================
#   Raw: Very comfortable, very helpful staff, delicious breakfast, very convenient to metro or ferry into the centre.
#   Predicted topic: hotel (auto)
#   Prediction: Positive (conf 1.0000)
#   TOWARD: [(np.str_('delicious'), 0.05071941358423033), (np.str_('comfortable'), 0.04415363985525076), (np.str_('convenient'), 0.04272020341543451), (np.str_('helpful'), 0.04158286643871983), (np.str_('centre'), 0.016304703190348938)]
#   AWAY: [(np.str_('or'), -0.02415972164540127), (np.str_('into'), -0.008388430517196057)]

# %% [markdown]
# ---
# ## 🔄 Step 9: Counterfactual Generation

# %%
# --- 9.1 Configure Groq API ---
import requests, json, time
API_key = input('Enter Your API Key: ').strip()
GROQ_API_KEY = API_key
GROQ_MODEL   = "openai/gpt-oss-120b"
GROQ_URL     = "https://api.groq.com/openai/v1/chat/completions"

def call_llm(prompt, timeout=60):
    headers = {
        "Authorization": f"Bearer {GROQ_API_KEY}",
        "Content-Type":  "application/json",
    }
    payload = {
        "model":       GROQ_MODEL,
        "messages":    [{"role": "user", "content": prompt}],
        "stream":      False,
        "temperature": 0.7,
    }
    r = requests.post(GROQ_URL, headers=headers, json=payload, timeout=timeout)
    if not r.ok:
        print(f"  ❌ HTTP {r.status_code}: {r.text}")   # in ra chi tiết lỗi
    r.raise_for_status()
    return r.json()["choices"][0]["message"]["content"].strip()

# Test + liệt kê models có sẵn
try:
    # Lấy danh sách models
    r = requests.get(
        "https://api.groq.com/openai/v1/models",
        headers={"Authorization": f"Bearer {GROQ_API_KEY}"}
    )
    models = [m["id"] for m in r.json().get("data", [])]
    print("Models available on your account:")
    for m in models:
        print(f"  - {m}")
except Exception as e:
    print(f"Could not list models: {e}")

# Test call
try:
    test = call_llm("Say OK only.", timeout=15)
    print(f"\n✅ Groq API ready! Model: {GROQ_MODEL}")
    print(f"   Test: {test}")
except Exception as e:
    print(f"⚠️ Failed: {e}")
# --- 9.2 Generate Counterfactual with Groq ---
counterfactuals = []

result     = lime_results[0]
tweet      = result['tweet']
topic      = result['topic']
pred       = result['prediction']
pred_label = pred['sentiment']

if pred_label == 'Negative':   target_sentiment = 'Positive'
elif pred_label == 'Positive': target_sentiment = 'Negative'
else:                          target_sentiment = 'Positive'

pos_words_str = ", ".join([f"'{w}' ({wt:+.4f})" for w, wt in result['positive_words'][:5]])
neg_words_str = ", ".join([f"'{w}' ({wt:+.4f})" for w, wt in result['negative_words'][:5]])

print(f"\n{'='*70}")
print(f"Groq Counterfactual Generation")
print(f"{'='*70}")
print(f"  Original ({pred_label}, conf: {pred['confidence']:.4f}):\n    {tweet}")
print(f"  Words TOWARD '{pred_label}': {pos_words_str}")
print(f"  Words AWAY from '{pred_label}': {neg_words_str}")

prompt = f"""You are a sentiment analysis assistant. Rewrite the following tweet to change its sentiment from {pred_label} to {target_sentiment}.

Original Tweet: "{tweet}"
Target Sentiment: {target_sentiment}

LIME analysis:
- Words pushing TOWARD current sentiment: {pos_words_str}
- Words pushing AWAY from current sentiment: {neg_words_str}

Modify the minimum number of words (focus on the TOWARD words) to flip sentiment to {target_sentiment}.
Return ONLY the rewritten tweet. No explanations, no quotes, no extra text."""

cf_text = tweet
api_status = "failed"

for attempt in range(1, 4):
    try:
        cf_text = call_llm(prompt, timeout=60)
        for q in ['"', "'"]:
            if cf_text.startswith(q) and cf_text.endswith(q):
                cf_text = cf_text[1:-1]
        api_status = "success"
        print(f"\n  Counterfactual:\n    {cf_text}")
        break
    except Exception as e:
        print(f"  Attempt {attempt} failed: {e}")
        if attempt < 3:
            time.sleep(5)
        else:
            print(" Falling back to original tweet.")

counterfactuals.append({
    'original': tweet, 'counterfactual': cf_text,
    'topic': topic, 'original_prediction': pred,
    'target_sentiment': target_sentiment, 'attack_status': api_status,
    'lime_positive_words': result['positive_words'],
    'lime_negative_words': result['negative_words'],
})
# --- 10.1 Re-predict and compare ---

def compare_predictions(original_text, counterfactual_text, topic_str, original_pred):
    """Compare predictions between original and counterfactual tweets."""
    cf_pred = predict_sentiment(counterfactual_text, topic_str)

    # Probability deltas
    deltas = {}
    for cls in original_pred['probabilities']:
        deltas[cls] = cf_pred['probabilities'][cls] - original_pred['probabilities'][cls]

    # Word-level diff
    orig_words = set(original_text.lower().split())
    cf_words   = set(counterfactual_text.lower().split())

    return {
        'counterfactual_prediction': cf_pred,
        'deltas': deltas,
        'words_removed': orig_words - cf_words,
        'words_added':   cf_words - orig_words,
        'flipped': original_pred['sentiment'] != cf_pred['sentiment'],
    }

# Run comparisons
print("=" * 80)
print("SIDE-BY-SIDE COMPARISON: Original vs. Counterfactual")
print("=" * 80)

comparison_results = []

for i, cf in enumerate(counterfactuals, 1):
    comp = compare_predictions(
        cf['original'], cf['counterfactual'], cf['topic'], cf['original_prediction']
    )
    comparison_results.append(comp)

    orig_pred = cf['original_prediction']
    cf_pred   = comp['counterfactual_prediction']

    print(f"\n{'-'*80}")
    print(f"Example {i}  [status: {cf['attack_status']}]")
    print(f"{'-'*80}")
    print(f"  Original:       {cf['original']}")
    print(f"  Counterfactual: {cf['counterfactual']}")
    print()
    print(f"  Original prediction:      {orig_pred['sentiment']} ({orig_pred['confidence']:.4f})")
    print(f"  Counterfactual prediction: {cf_pred['sentiment']} ({cf_pred['confidence']:.4f})")
    print(f"  Sentiment flipped: {'✅ YES' if comp['flipped'] else '❌ NO'}")
    print()
    print(f"  Probability deltas:")
    for cls, delta in comp['deltas'].items():
        arrow = "▲" if delta > 0 else "▼" if delta < 0 else "─"
        print(f'    {cls}: {delta:+.4f} {arrow}')
    print()
    print(f"  Words Removed: {comp['words_removed']}")
    print(f"  Words Added:   {comp['words_added']}")

print(f"\n✅ Comparison complete.")
# --- 11.1 Generate full explanations ---

def format_explanation(lime_result, counterfactual, comparison):
    """Format a complete human-readable explanation."""
    orig = lime_result['tweet']
    pred = lime_result['prediction']['sentiment']
    conf = lime_result['prediction']['confidence']
    cf_text = counterfactual['counterfactual']
    cf_pred = comparison['counterfactual_prediction']['sentiment']
    cf_conf = comparison['counterfactual_prediction']['confidence']

    # LIME top words
    pos_words = [f"'{w}' ({wt:+.4f})" for w, wt in lime_result['positive_words'][:3]]
    neg_words = [f"'{w}' ({wt:+.4f})" for w, wt in lime_result['negative_words'][:3]]

    lines = []
    lines.append(f"📌 EXPLANATION")
    lines.append(f"")
    lines.append(f"The model predicted **{pred}** (confidence: {conf:.1%}) for:")
    lines.append(f'  \\"{orig}\"')
    lines.append(f"")
    lines.append(f"🔍 LIME — Words pushing TOWARD '{pred}': {', '.join(pos_words)}")
    lines.append(f"🔍 LIME — Words pushing AWAY from '{pred}': {', '.join(neg_words)}")
    lines.append(f"")
    lines.append(f"🤖 Ollama Counterfactual Generation:")
    lines.append(f"   Status: {counterfactual['attack_status']}")
    lines.append(f"")
    if comparison['flipped']:
        lines.append(f"✅ By modifying the tweet, the sentiment flips to **{cf_pred}** "
                      f"(confidence: {cf_conf:.1%}).")
    else:
        lines.append(f"❌ After modification, the model still predicts "
                      f"**{cf_pred}** (confidence: {cf_conf:.1%}) — the sentiment "
                      f"did not flip.")
    lines.append(f"")
    lines.append(f"Counterfactual tweet:")
    lines.append(f'  \\"{cf_text}\"')

    return "\n".join(lines)

# Print all explanations
print("=" * 80)
print("FULL EXPLANATIONS — Steps 8–11 Combined (LIME + Ollama)")
print("=" * 80)

for i in range(len(counterfactuals)):
    print(f"\n{'━'*80}")
    print(f"  Tweet {i+1}")
    print(f"{'_'*80}")
    expl = format_explanation(lime_results[i], counterfactuals[i], comparison_results[i])
    print(expl)

print(f"\n Full explanations generated for all examples.")

# --- 9.3 Save counterfactual explanations to text files ---
cf_output_dir = './counterfactual_Example'
os.makedirs(cf_output_dir, exist_ok=True)

for i in range(len(counterfactuals)):
    expl = format_explanation(lime_results[i], counterfactuals[i], comparison_results[i])
    out_path = os.path.join(cf_output_dir, f'counterfactual_example_{i+1}.txt')
    with open(out_path, 'w', encoding='utf-8') as f:
        f.write(expl)
    print(f"Saved: {out_path}")
# Out:
# Enter Your API Key: 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
# Models available on your account:
#   - allam-2-7b
#   - openai/gpt-oss-120b
#   - meta-llama/llama-prompt-guard-2-22m
#   - openai/gpt-oss-20b
#   - groq/compound-mini
#   - meta-llama/llama-prompt-guard-2-86m
#   - groq/compound
#   - openai/gpt-oss-safeguard-20b
#   - qwen/qwen3.6-27b
#   - qwen/qwen3.8-27b
#   - canopylabs/orpheus-arabic-saudi
#   - canopylabs/orpheus-v1-english
#   - whisper-large-v3
#   - whisper-large-v3-turbo
#
# ✅ Groq API ready! Model: openai/gpt-oss-120b
#    Test: OK
#
# ======================================================================
# Groq Counterfactual Generation
# ======================================================================
#   Original (Negative, conf: 0.8247):
#     Another patch, another broken champion ruining ranked. The balance team actually has no idea what they are doing. Vanguard keeps crashing my PC and cost me 50 LP today. Im so done with this game 🤬 #LeagueOfLegends
#   Words TOWARD 'Negative': 'another' (+0.0918), 'ruining' (+0.0815), 'done' (+0.0737), 'crashing' (+0.0660), 'my' (+0.0545)
#   Words AWAY from 'Negative': 'champion' (-0.0398), 'pc' (-0.0350), 'are' (-0.0208), 'lp' (-0.0168)
#
#   Counterfactual:
#     New patch, another broken champion enhancing ranked. The balance team actually has no idea what they are doing. Vanguard keeps running the PC and cost me 50 LP today. I'm so hopeful with this game 😊 #LeagueOfLegends
# ================================================================================
# SIDE-BY-SIDE COMPARISON: Original vs. Counterfactual
# ================================================================================
#
# --------------------------------------------------------------------------------
# Example 1  [status: success]
# --------------------------------------------------------------------------------
#   Original:       Another patch, another broken champion ruining ranked. The balance team actually has no idea what they are doing. Vanguard keeps crashing my PC and cost me 50 LP today. Im so done with this game 🤬 #LeagueOfLegends
#   Counterfactual: New patch, another broken champion enhancing ranked. The balance team actually has no idea what they are doing. Vanguard keeps running the PC and cost me 50 LP today. I'm so hopeful with this game 😊 #LeagueOfLegends
#
#   Original prediction:      Negative (0.8247)
#   Counterfactual prediction: Positive (0.3908)
#   Sentiment flipped: ✅ YES
#
#   Probability deltas:
#     Negative: -0.5021 ▼
#     Neutral: +0.1559 ▲
#     Positive: +0.3462 ▲
#
#   Words Removed: {'im', '🤬', 'crashing', 'my', 'done', 'ruining'}
#   Words Added:   {'running', "i'm", 'hopeful', 'new', '😊', 'enhancing'}
#
# ✅ Comparison complete.
# ================================================================================
# FULL EXPLANATIONS — Steps 8–11 Combined (LIME + Ollama)
# ================================================================================
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Tweet 1
# ________________________________________________________________________________
# 📌 EXPLANATION
#
# The model predicted **Negative** (confidence: 82.5%) for:
#   \"Another patch, another broken champion ruining ranked. The balance team actually has no idea what they are doing. Vanguard keeps crashing my PC and cost me 50 LP today. Im so done with this game 🤬 #LeagueOfLegends"
#
# 🔍 LIME — Words pushing TOWARD 'Negative': 'another' (+0.0918), 'ruining' (+0.0815), 'done' (+0.0737)
# 🔍 LIME — Words pushing AWAY from 'Negative': 'champion' (-0.0398), 'pc' (-0.0350), 'are' (-0.0208)
#
# 🤖 Ollama Counterfactual Generation:
#    Status: success
#
# ✅ By modifying the tweet, the sentiment flips to **Positive** (confidence: 39.1%).
#
# Counterfactual tweet:
#   \"New patch, another broken champion enhancing ranked. The balance team actually has no idea what they are doing. Vanguard keeps running the PC and cost me 50 LP today. I'm so hopeful with this game 😊 #LeagueOfLegends"
#
#  Full explanations generated for all examples.
# Saved: ./counterfactual_Example/counterfactual_example_1.txt

# %% [markdown]
# ---
# ## 📦 Step 10: Reproducibility Artifacts Export
#
# Persist the run configuration and the Groq prompt templates so the full run can be reproduced or
# audited later. The filtered/deduplicated id list was already saved in Step 2.2b.

# %%
run_config = {
    'SEED': SEED,
    'MODEL_NAME': MODEL_NAME,
    'MAX_LEN': MAX_LEN,
    'EMBED_BATCH_SIZE': EMBED_BATCH_SIZE,
    'BATCH_TRAIN': BATCH_TRAIN,
    'BATCH_EVAL': BATCH_EVAL,
    'ROBERTA_DIM': ROBERTA_DIM,
    'TOPIC_EMB_DIM': TOPIC_EMB_DIM,
    'DROPOUT_RATE': DROPOUT_RATE,
    'NUM_TOPICS': int(NUM_TOPICS),
    'NUM_CLASSES': int(NUM_CLASSES),
    'main_model_epochs_cap': EPOCHS,
    'main_model_early_stopping_patience': 5,
    'ablation_variants': ABLATION_VARIANTS,
    'ablation_epoch_budgets': EPOCH_BUDGETS,
    'ablation_n_seeds': N_SEEDS,
    'ablation_patience_by_epochs': {15: 4, 30: 5},
    'GROQ_MODEL': GROQ_MODEL,
    'trainable_params': int(trainable_params),
    'filtered_deduped_rows': int(len(df)),
    'filtered_ids_file': './artifacts/filtered_ids.csv',
}

groq_prompts = {
    'single_tweet_demo_prompt_template': (
        "You are a sentiment analysis assistant. Rewrite the following tweet to change its "
        "sentiment from {pred_label} to {target_sentiment}.\n\n"
        "Original Tweet: \"{tweet}\"\n"
        "Target Sentiment: {target_sentiment}\n\n"
        "LIME analysis:\n"
        "- Words pushing TOWARD current sentiment: {pos_words_str}\n"
        "- Words pushing AWAY from current sentiment: {neg_words_str}\n\n"
        "Modify the minimum number of words (focus on the TOWARD words) to flip sentiment to "
        "{target_sentiment}.\nReturn ONLY the rewritten tweet. No explanations, no quotes, no extra text."
    ),
}

os.makedirs('./artifacts', exist_ok=True)
with open('./artifacts/run_config.json', 'w', encoding='utf-8') as f:
    json.dump(run_config, f, indent=2, default=str)
with open('./artifacts/groq_prompts.json', 'w', encoding='utf-8') as f:
    json.dump(groq_prompts, f, indent=2)

print("Saved: ./artifacts/run_config.json")
print("Saved: ./artifacts/groq_prompts.json")
print(f"Filtered id list already saved at {run_config['filtered_ids_file']} ({run_config['filtered_deduped_rows']} ids)")
# Out:
# Saved: ./artifacts/run_config.json
# Saved: ./artifacts/groq_prompts.json
# Filtered id list already saved at ./artifacts/filtered_ids.csv (44396 ids)
